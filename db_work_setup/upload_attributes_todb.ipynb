# %%
import pandas as pd
import yaml
from sqlalchemy import create_engine

# %%
with open("../config/main.yaml", "r") as f:
    config = yaml.load(f, Loader=yaml.FullLoader)

with open("../config/keys.yaml", "r") as f:
    keys = yaml.load(f, Loader=yaml.FullLoader)

import psycopg2

psy_engine = psycopg2.connect(
    database=config['database']['name'],
    user=config['database']['user'],
    password=keys['postgres'],
    host=config['database']['host'],
    port='5432'
)

cur = psy_engine.cursor()

# %%
# load in csv for attributes
df = pd.read_csv("/home/ubuntu/work/attributes/final.csv").iloc[:, 1:]

# %%
df = df.drop_duplicates(subset = 'corpusid')

# %%
sql = create_engine(f'postgresql://postgres:{keys["postgres"]}@{config["database"]["host"]}:5432/postgres')

# %%
df.to_sql('attributes', con=sql, if_exists='replace', chunksize = 10000)
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.to_sql('attributes', con=sql, if_exists='replace', index = False, chunksize = 10000)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:2987, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2830 """
#    2831 Write records stored in a DataFrame to a SQL database.
#    2832
#    (...)
#    2983 [(1,), (None,), (2,)]
#    2984 """  # noqa:E501
#    2985 from pandas.io import sql
# -> 2987 return sql.to_sql(
#    2988     self,
#    2989     name,
#    2990     con,
#    2991     schema=schema,
#    2992     if_exists=if_exists,
#    2993     index=index,
#    2994     index_label=index_label,
#    2995     chunksize=chunksize,
#    2996     dtype=dtype,
#    2997     method=method,
#    2998 )
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/sql.py:686, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     683 if if_exists not in ("fail", "replace", "append"):
#     684     raise ValueError(f"'{if_exists}' is not valid for if_exists")
# --> 686 pandas_sql = pandasSQL_builder(con, schema=schema)
#     688 if isinstance(frame, Series):
#     689     frame = frame.to_frame()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/sql.py:754, in pandasSQL_builder(con, schema)
#     752         raise ImportError("Using URI string without sqlalchemy installed.")
#     753     else:
# --> 754         con = sqlalchemy.create_engine(con)
#     756 if sqlalchemy is not None and isinstance(con, sqlalchemy.engine.Connectable):
#     757     return SQLDatabase(con, schema=schema)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/sqlalchemy/util/deprecations.py:309, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     302     if m in kwargs:
#     303         _warn_with_version(
#     304             messages[m],
#     305             versions[m],
#     306             version_warnings[m],
#     307             stacklevel=3,
#     308         )
# --> 309 return fn(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/sqlalchemy/engine/create.py:530, in create_engine(url, **kwargs)
#     527 kwargs.pop("empty_in_strategy", None)
#     529 # create url.URL object
# --> 530 u = _url.make_url(url)
#     532 u, plugins, kwargs = u._instantiate_plugins(kwargs)
#     534 entrypoint = u._get_entrypoint()
#
# File ~/anaconda3/lib/python3.10/site-packages/sqlalchemy/engine/url.py:725, in make_url(name_or_url)
#     718 """Given a string or unicode instance, produce a new URL instance.
#     719
#     720 The given string is parsed according to the RFC 1738 spec.  If an
#     721 existing URL object is passed, just returns the object.
#     722 """
#     724 if isinstance(name_or_url, util.string_types):
# --> 725     return _parse_rfc1738_args(name_or_url)
#     726 else:
#     727     return name_or_url
#
# File ~/anaconda3/lib/python3.10/site-packages/sqlalchemy/engine/url.py:786, in _parse_rfc1738_args(name)
#     783     return URL.create(name, **components)
#     785 else:
# --> 786     raise exc.ArgumentError(
#     787         "Could not parse rfc1738 URL from string '%s'" % name
#     788     )
#
# ArgumentError: Could not parse rfc1738 URL from string '
#     SELECT * FROM attributes;
# '

# %%
from sqlalchemy import create_engine, text

engine = create_engine(f'postgresql://postgres:{keys["postgres"]}@{config["database"]["host"]}:5432/postgres')

# Query to pull in corpus IDs

sql = '''
    SELECT * FROM attributes;
'''

# Context manager to open the connection to the database and execute the query. 
with engine.connect() as conn:
    query = conn.execute(text(sql))
    
# Get all records and store in dataframe
attributes = pd.DataFrame(query.fetchall())

# %%
attributes.head()
# Out:
#    index   corpusid                                        externalids  \
# 0      0   52273203  {"ACL": null, "DBLP": null, "ArXiv": null, "MA...
# 1      1   23708908  {"ACL": null, "DBLP": null, "ArXiv": null, "MA...
# 2      2   13232625  {"ACL": null, "DBLP": null, "ArXiv": null, "MA...
# 3      3   73484844  {"ACL": null, "DBLP": null, "ArXiv": null, "MA...
# 4      4  229159752  {"ACL": null, "DBLP": null, "ArXiv": null, "MA...
#
#                                                  url  \
# 0  https://www.semanticscholar.org/paper/39063bcd...
# 1  https://www.semanticscholar.org/paper/6ec7c156...
# 2  https://www.semanticscholar.org/paper/c8566272...
# 3  https://www.semanticscholar.org/paper/d4c9b2fa...
# 4  https://www.semanticscholar.org/paper/7f13abe2...
#
#                                                title  \
# 0  Large conformational changes of a highly dynam...
# 1  Drug sensitivity profiling identifies potentia...
# 2  Men's memory for women's sexual-interest and r...
# 3  The Reactive Plasticity of Hippocampal Ionotro...
# 4  High Mortality Rate in Adult COVID-19 Inpatien...
#
#                                              authors  \
# 0  {"{\"authorId\": \"51285510\", \"name\": \"Isa...
# 1  {"{\"authorId\": \"5699001\", \"name\": \"H. K...
# 2  {"{\"authorId\": \"4425040\", \"name\": \"T. T...
# 3  {"{\"authorId\": \"2225106\", \"name\": \"A. M...
# 4  {"{\"authorId\": \"7685173\", \"name\": \"Saee...
#
#                                          venue  \
# 0                       Communications Biology
# 1                                   OncoTarget
# 2                                         None
# 3  International Journal of Molecular Sciences
# 4      Journal of Multidisciplinary Healthcare
#
#                      publicationvenueid    year  referencecount  \
# 0  069e05e7-ca35-41d0-a8c7-bdc9ec6a82af  2018.0              28
# 1  106ecc86-1801-4b36-a05c-d36db69a968c  2017.0              46
# 2                                  None  2011.0              36
# 3  8506a01a-40b8-4e6f-bbb8-ce2492139c15  2019.0              97
# 4  12e5e550-28bd-401c-a348-f347956deec4  2020.0              37
#
#    citationcount  influentialcitationcount  isopenaccess  \
# 0             13                         0          True
# 1             24                         0          True
# 2             13                         0          True
# 3             15                         1          True
# 4             17                         1          True
#
#                                      s2fieldsofstudy         publicationtypes  \
# 0  {"{\"category\": \"Biology\", \"source\": \"s2...         {JournalArticle}
# 1  {"{\"category\": \"Biology\", \"source\": \"s2...         {JournalArticle}
# 2  {"{\"category\": \"Psychology\", \"source\": \...                 {Review}
# 3  {"{\"category\": \"Biology\", \"source\": \"s2...  {Review,JournalArticle}
# 4  {"{\"category\": \"Medicine\", \"source\": \"s...  {JournalArticle,Review}
#
#   publicationdate                                            journal  \
# 0      2018-09-03  {"name": "Communications Biology", "pages": nu...
# 1      2017-10-31  {"name": "Oncotarget", "pages": "97516 - 97527...
# 2      2011-09-01  {"name": "Applied Cognitive Psychology", "page...
# 3      2019-02-27  {"name": "International Journal of Molecular S...
# 4      2020-12-01  {"name": "Journal of Multidisciplinary Healthc...
#
#                     updated       id
# 0  2023-03-31T01:28:37.897Z  5692596
# 1  2023-04-05T06:18:15.837Z  5692609
# 2  2023-04-05T08:18:02.240Z  5692611
# 3  2023-05-20T17:20:54.230Z  5692615
# 4  2023-05-23T13:34:07.581Z  5692620

# %%
psy_engine.commit()
cur.close()
psy_engine.close()
