# %% [markdown]
# # Setup

# %%
import os
import pandas as pd
import numpy as np
import json


from tqdm.auto import tqdm
import time

# %%
import yaml
with open("../config/main.yaml", "r") as f:
    config = yaml.load(f, Loader=yaml.FullLoader)

with open("../config/keys.yaml", "r") as f:
    keys = yaml.load(f, Loader=yaml.FullLoader)

root_path = config['paths']['root']
mount_path = os.path.join(root_path, config['paths']['papers'])
working_path = os.path.join(root_path, config['paths']['wkdir'])

# %% [markdown]
# # Get Full Text

# %%
import requests
# full text
# follow s3 link
full_text = requests.get("http://api.semanticscholar.org/datasets/v1/release/latest/dataset/s2orc",
                      headers={'x-api-key':keys['x-api-key']}).json()

# %%
full_text
# Out:
# {'name': 's2orc',
#  'description': 'Full-body paper text parsed from open-access PDFs. Identifies structural elements such as paragraphs, sections, and bibliography entries.\n5M records in 30 4GB files.',
#  'README': 'Semantic Scholar Academic Graph Datasets\n\nThe "s2orc" dataset contains parsed full-body text from selected papers.\n\nA subset of this data was previously released (in a different format) as S2ORC https://github.com/allenai/s2orc\n\nThe body text is parsed from PDF documents using Grobid, documented at https://grobid.readthedocs.io.\nIts output is converted from XML into a single string with a set of annotation spans.\n\nSCHEMA\n - externalIds: IDs of this paper in different catalogs\n - content:\n   - source:\n\t   - pdfUrls: URLs to the PDF\n\t   - oaInfo: license/url/status information from Unpaywall\n   - text: Full body text as a single string\n   - annotations: Annotated spans of the full body text\n\n\nLICENSE\nThis collection is licensed under ODC-BY. (https://opendatacommons.org/licenses/by/1.0/)\n\nBy downloading this data you acknowledge that you have read and agreed to all the terms in this license.\n\nATTRIBUTION\nWhen using this data in a product or service, or including data in a redistribution, please cite the following paper:\n\n@inproceedings{lo-wang-2020-s2orc,\n    title = "{S}2{ORC}: The Semantic Scholar Open Research Corpus",\n    author = "Lo, Kyle  and Wang, Lucy Lu  and Neumann, Mark  and Kinney, Rodney  and Weld, Daniel",\n    booktitle = "Proceedings of the 58th Annual Meeting of the Association for Computational Linguistics",\n    month = jul,\n    year = "2020",\n    address = "Online",\n    publisher = "Association for Computational Linguistics",\n    url = "https://www.aclweb.org/anthology/2020.acl-main.447",\n    doi = "10.18653/v1/2020.acl-main.447",\n    pages = "4969--4983"\n}\n',
#  'files': ['https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_0249e9d0-0537-4baa-bab3-78b0c18ce031.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=oWps4mkrPsBTQXuzAeaXeMRTfxc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_03b863d8-e4f9-4ca4-8e2e-135c43037034.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=H07Y2B6escom2MxU%2B%2F2JLbtkw%2Fk%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_0b8065d5-00f3-4eb0-8919-b403872088a4.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=YHXG7iU4fLEgp3CwgH53wt2RZQw%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_1229b209-565d-4088-9df7-4fc788cb9d17.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=lz0NJnxspjkoBzA8OQl0zVLdSZ0%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_1397d34e-a783-4521-9dbb-8916d6a1deb6.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=P4VqRVK7kkHRhlkpSpPmi8Ek2NY%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_1ac732c6-b47f-4cde-9939-9e9e66910c98.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=1SVlDzfwggalxOMfPJwe0Dhhn0s%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_2985845c-3fd6-48c7-88b5-3d0cce76f294.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=94GANN6Irr19TUsE27czwNQJfE0%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_37ecfb2b-6f7d-4c76-bbf4-0aa25c33d2e4.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=Wpscyy1jxeoW840%2BhqF2gTjRzCE%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_3a22b8b7-2e90-41e3-896c-bf0ca8c2e556.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=QvHcEkJmtTNcp23cvKjSAUwjwfI%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_607d0dfc-d008-4ac2-9795-3265be213d55.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=nWsH8mEKanRot3SwyJAO%2FsjFwEw%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_617559e0-aaa4-48bc-9485-80ee1bdeab93.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=ZCPxpqOJ2B2elhbUQiysts1%2BBAg%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_6862c0e5-202d-4678-b74e-af06dda5d9e1.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=5PqO20nKLBH9uY%2FmG0cObEv8JFc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_71691bcf-71ad-443e-b000-776ad9537657.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=V22ANt3zqZSAq06fYs7z%2F0qHz5Y%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_789ee8b7-0bbd-415b-87d7-397be9114411.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=5YQoaoBDu4pWTXhRgzsS6ZOWUS8%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_82eefc4a-ee28-4a0d-ac87-c0ddaa346df4.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=7TvQ6ZmEEX7NjKItkdjdgsR%2BAXY%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_84ca984b-500b-47e8-a37e-8342875fcfd1.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=Zhl4pJXh8qKiGztZfmRTkehrku0%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_8ed0f6db-be26-4515-a977-bf1959595bd9.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=%2F44f5ieiDczJzIsGW35E3myZzr4%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_9552f5dc-d22a-4a50-8953-d91d55d9ee4e.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=Bn25RRNStuFwl3VuCh7jhdjFNCM%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_973e1b17-f2eb-4338-955d-2e5d094f2917.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=2CQoIejvHoVQM2qEx5yWDUsdeXQ%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_9abad2f7-cb94-480f-84c8-5495cbd34049.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=SRul6KaG3EKEF%2FshpLxko76vKeY%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_a7220fc6-b74b-4d10-8778-97c7b528f437.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=ImPmJvFiEwQyPypyxOFQ4bL2fj8%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_a73e5a31-669e-4082-95a8-694adfabdbdc.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=agl93kYtnnd7he%2FKb9LZeYGKtko%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_ab29858d-7aeb-4b52-b335-6a8611676910.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=la5J87pwdq5j3pSHQ2kwi7dOKBI%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_b68d59dc-9797-499c-b8bb-845ff681304c.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=H%2BvtB23wk11DdxCMRYFhwBEg%2Fg4%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_bceeba25-de1e-4ead-9923-ccd04db1f9c3.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=rsFfrV7t51oUkMQyAnBgao5CrxM%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_c3391f7a-d98b-4d5b-baea-d3d3e6bf07e9.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=wD0Pdc0mN%2BMK7OW8qGsUcl9dzFQ%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_c828c1db-d113-40a7-9490-a59da00fe4b3.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=AvP1jW3oh00fsYgtjpXhDD6Fp9M%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_e36c6291-3aac-402b-ae89-db49929cff3d.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=%2BRgDwgPxYSZZ8%2B7NfUMx87ygw28%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_e40a8f21-07ae-490b-a858-a8f07c1598ef.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=5dtIRBuDLpNx8GhgytKGNk5kw4M%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812',
#   'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_eb5dfd99-1799-4e83-8307-3318d974b195.gz?AWSAccessKeyId=ASIA5BJLZJPWQCHMYIK3&Signature=6fM9SD5VNN6Gnica79V%2B2x9qUDc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDpDYlTH4ZpVMKIBYz%2Fy4qCmpx7CEPCMCl74baAMOvp9AiBHOvZeHumApjQqN9wUu7fJV%2Fah0HQcDOa8dEVM8ZL5vyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMAMsZ3ju9qyGeC3lXKtwD3qO0jVAh4n0CiJI1d4my9Le6AYpQRjspVWmltyC%2BU1GE44mVdz537tGGQvo84UiN%2FFmhP1O19%2FiEgOamhTnRgAE9lXXwFCElQ2VeYvPatELN5Q62TmlTvY8GEgKkIQeNLEv9GdC2l%2BAbymJGRrO1FsnFhhFmEzyFrMHUYeJ%2BjrhjxRAdT%2FcQHQ8sVLWy68GaUXGN51muVgeHANjYP9Ldkmqr4X8mrjAD%2Ftua2m8l3jie5a0jVvPv%2FTc7QIEi3F2BLzhQqsdFZPMIZ%2FDRfCmkwOUKki5%2BVyPUMC3p%2B3b79vkfJyZFg7XVvzx3x%2F5A%2BOIPpjrNqBQRrhrsr46sUnoFhwlQEJpM4nmMvb1dLb0j062Ncvy62Mmrwgx2320r%2BV7jgLGCv6NtuWh7K30Svq8OUTLVpVw2bQByOG7IKDA6xcMWBiwmaky0HH0g06ocD6G26C39rd3j6iz3a3OTDWoa3niokJKY3IL5hdDoE36HRE3w7io5NZS2f6W2ghq58JWGwW5%2BUFrq5IWt3a76TzhEJWYHT5jgJFFffpGwLNejOzuKKwveYjWZkPc4OHgAWenog%2BbWS%2BxB3U7XxNFk%2FnfIzruxbDgJzC03kjS36PfwWBesuGXHulOBCJp%2FB9gwleyXpAY6pgHfN%2BcSZKEXV0asPF3upY8NTaUGKxfEIFV5tB53Za4BnH7VQ3x8OmcKs1LQymuv7SqSt8E5pi2QGtEWNqg2UQLc7hpQJpqHp3Ejy0sx1C0xMrR63NjKx8okjz2TXKS8OwI2dAAisWJ8vF%2ByfkT%2Fcoh6tuo7wErW2UEujdYEEyi3QCWkb051Y6Qka6b73L1%2F6uhGLf6%2BaFx7M2cjm4rU5nqq%2BffJK3q%2B&Expires=1687111812']}

# %%
# Attributes
# follow s3 link
attributes = requests.get("http://api.semanticscholar.org/datasets/v1/release/latest/dataset/papers",
                      headers={'x-api-key':keys['x-api-key']}).json()

# %%
pd.DataFrame(papers).loc[0, 'files']
# Out:
# 'https://ai2-s2ag.s3.amazonaws.com/staging/2023-06-06/s2orc/20230609_111759_00053_f77bs_0249e9d0-0537-4baa-bab3-78b0c18ce031.gz?AWSAccessKeyId=ASIA5BJLZJPWYMPCSPN4&Signature=o%2BGIUncrcbBm0RfqWVmkJklGGkc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEHkaCXVzLXdlc3QtMiJGMEQCIDNH9fgxkkKHnwRqafY9HNprd6qu3OPvmyAHz7oq3QJ8AiB54ljHHa%2Fpye1nhFx9TDNxcItBQeHaXc85SXRkHgJ6qyqIBAjC%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDg5NjEyOTM4NzUwMSIMxQahPPC6d63wSVytKtwDRDZsEJ4fPD0R7v60ptqoqmAHDX8X7FtYiPrVpUrmco4i1KogPHzEUzd1%2BkTViBPXhH3Z9E9lcOdMe5grqBNLq6E3PjikwX2chb6XV2NZw%2FJ1Q1Uc6gHRsiBGFrYmQHxpsV8NXC2RjAyFnJ6UoksjuROUi0%2B8IUYJGNlVtU8v67B7TJ66MKwkALI5zhN8jrrvjNeyTotQWu4xTNFLGgNVBx2ba1cSSqN4eFZCMV5Lv4AxDV2l42%2F3bsz%2BIxRPYEc2H1y3l5GQxBEZedlbecyXbImfJxVwfALzcNoAOS%2FejFqb3FXt5FEw6KWs0ZVrKeXvAkcZ2r30oNUaS1zW97q5LXXNT1Y8QomBeYgHAAp5uUnmbE101%2FNQYtfcd8PWcXuyuWtRzFGaRKEWW195IFNATGYjDShcfuN6BCJDi8nrHT4Dx7SOkVaaJhguALWiKroq8LqWzui3wcyvsgPw3ttRHAQB6xSLRu6FYNff4bhLDZ6pnL0iEkHIgBdzbX6gniGqGGDinNBTI6EeNN4lGHBht39hHFzekQjUnF8IJNiZ4mt6yf%2BRkA%2FJUT7tckIChqACej2noNFtbfenE9DTnlXPass7FfLlhyDT5kQudFfkbp2pr%2BEa9j5qfSplWNgwsPuXpAY6pgFT3AHUS0TZpp6Fem%2FGThIC3RKbCmj7S6K9UzbY8VSeNloKN3BS0wGNXfUGnNRNZn7bQdhPvnxtMMY5uj5w322WsFYKNAIgABVpDqKOKrVpDel5NN2KvUw9qG%2FFmethavjyJX6t%2BlwoLh4ibsJo583DOM9ihqbAV1fH2dFA3sM%2FDAxrnu%2FIADqE9%2ByClMJjnlO9qF%2BhNXJ0HRMoWHk%2B9JbgWrQmOpId&Expires=1687111165'

# %%
# download text
r = requests.get(pd.DataFrame(papers).loc[0, 'files'], allow_redirects=True)

# %%
with open('facebook.ico', 'wb')
# Out:
# <Response [200]>

# %% [markdown]
# # Parse Text

# %%
# Get all file paths. It is in attributes but it is the full papers
import glob
attribute_files = glob.glob("".join([mount_path, '/*?[!.gz|!.zip]']))
print(len(attribute_files))
attribute_files
# Out:
# 29
# ['/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_0cadbe3e-d976-4ddd-a419-5338f4bdb9b9',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_1cf93f6a-2a54-4761-a6e2-be64df72abfd',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_277c5193-816a-41df-914a-63ce8739d3db',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_2867ec04-ebb0-4c0a-9cca-bab125db6b3a',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_3090aa34-c242-40a3-af8f-ddd0a091fd06',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_34b5fd04-aadf-4596-9d88-04fb2446f3ee',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_3dcdac3f-ae5e-40c5-b3aa-839df4c9fcab',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_3e82aa4a-c1aa-4a75-8ff8-8187d98a6091',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_4917e161-6ddb-4063-b531-2feca0882f0b',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_4fc33ccd-2d0a-4c83-b965-d38b89c6d268',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_637f0c35-6dad-4dfb-89a4-3875709a2a88',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_6c2fdaac-7adc-44a2-8a2d-2b5d541172a2',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_7b2aeb4e-f79f-483c-a9d0-8599ed706e73',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_7cc7d33c-3d96-420a-ba29-e7c8c28ef3ff',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_820ddc35-8b54-4771-910b-4adf3cee8b6a',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_8db7b95f-6567-4e43-aac2-95f8cee8bd3c',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_9741cb71-bb33-42b2-b819-f29858850e2d',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_977fc923-c650-4771-be0d-6914d4f160ae',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_9deef24f-5b21-480c-9bb4-d4d43cbe49bd',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_9e63c07b-b6ce-4a68-a165-29f551468698',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_b627808d-8810-4896-9491-b2511d8f3dca',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_b9ef1a6f-087c-46ff-b70d-98a39a774fb9',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_c660fbcd-4148-4e9e-adae-ff1140586c59',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_cf221546-ac15-4639-8baf-098d4796c113',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_dd0a78f8-8507-4c92-8b56-284ca228445c',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_f9a41976-913e-40e1-badd-3e0bb269515e',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_fceae11c-9237-4701-b25e-f1adca6c172d',
#  '/home/nick_lee_berkeley_edu/mount-attributes/20230609_070343_00047_bkw4d_ffcd05f8-ff22-4820-93c1-0d004bc650ab',
#  '/home/nick_lee_berkeley_edu/mount-attributes/extracted']

# %%
with open(attribute_files[0], 'r') as f: 
    f.seek(0)
    data = f.read(2000 - 0)

# %%
data
# Out:
# '{"corpusid":209821356,"externalids":{"ACL":null,"DBLP":null,"ArXiv":null,"MAG":"885611991","CorpusId":"209821356","PubMed":null,"DOI":null,"PubMedCentral":null},"url":"https://www.semanticscholar.org/paper/a12266fce7d3b22b5a4c9cac9c7a3675f9cc1f46","title":"星形细胞瘤热休克蛋白70（HSP70）表达的研究","authors":[{"authorId":"66573337","name":"王建中"},{"authorId":"80068024","name":"蔡晓东"},{"authorId":"66486956","name":"丁建军"},{"authorId":"81021948","name":"李维平"},{"authorId":"1474054841","name":"付友增"},{"authorId":"1475846842","name":"陈耕野"},{"authorId":"1996397447","name":"肖邦良"},{"authorId":"66480329","name":"毛伯镛"},{"authorId":"69408990","name":"罗宏"},{"authorId":"83269768","name":"张文燕"}],"venue":"","publicationvenueid":null,"year":2002,"referencecount":0,"citationcount":0,"influentialcitationcount":0,"isopenaccess":false,"s2fieldsofstudy":null,"publicationtypes":null,"publicationdate":null,"journal":{"name":"","pages":"165-167","volume":"7"},"updated":"2022-01-27T10:59:03.668Z"}\n{"corpusid":230732139,"externalids":{"ACL":null,"DBLP":null,"ArXiv":null,"MAG":"2205493012","CorpusId":"230732139","PubMed":null,"DOI":null,"PubMedCentral":null},"url":"https://www.semanticscholar.org/paper/be5a5156402d6fc632977f48ba46621196c642e1","title":"Années 2009 à 2014","authors":[{"authorId":"52049503","name":"Dreal Limousin"}],"venue":"","publicationvenueid":null,"year":2015,"referencecount":0,"citationcount":0,"influentialcitationcount":0,"isopenaccess":false,"s2fieldsofstudy":null,"publicationtypes":null,"publicationdate":"2015-10-23","journal":{"name":"","pages":null,"volume":""},"updated":"2022-01-27T13:19:23.917Z"}\n{"corpusid":118105413,"externalids":{"ACL":null,"DBLP":null,"ArXiv":null,"MAG":"379921969","CorpusId":"118105413","PubMed":null,"DOI":null,"PubMedCentral":null},"url":"https://www.semanticscholar.org/paper/022f1585041bbe99bb9ab26d6b379353ae3ad15e","title":"Self-organization of isotopic and drift-ware turbulence","authors":[{"authorId":"93856515","name":"A. Pushkarev"}],"venue":"","publicationv'

# %%
import jsonlines
temp_df = pd.DataFrame()
with jsonlines.open(attribute_files[0]) as f:
    count = 0
    for line in tqdm(f.iter()): 
        if count == 100: 
            break
        else: 
            temp_df = pd.concat([temp_df,pd.DataFrame([line])]) # reads json, converts to dataframe, preprocess functions and appends results to database
            count += 1
# Out:
# 0it [00:00, ?it/s]

# %%
temp_df.reset_index(inplace=True, drop=True)

# %%
tdf_2 = temp_df.query('isopenaccess == True')

# %%
tdf_2.url.str.rsplit('/')
# Out:
# 67    [https:, , www.semanticscholar.org, paper, 5f7...
# 93    [https:, , www.semanticscholar.org, paper, 2f6...
# Name: url, dtype: object

# %%
papers = json.loads(temp_df.to_json(orient = 'records'))

# %%
papers[0]
# Out:
# {'corpusid': 209821356,
#  'externalids': {'ACL': None,
#   'DBLP': None,
#   'ArXiv': None,
#   'MAG': '885611991',
#   'CorpusId': '209821356',
#   'PubMed': None,
#   'DOI': None,
#   'PubMedCentral': None},
#  'url': 'https://www.semanticscholar.org/paper/a12266fce7d3b22b5a4c9cac9c7a3675f9cc1f46',
#  'title': '星形细胞瘤热休克蛋白70（HSP70）表达的研究',
#  'authors': [{'authorId': '66573337', 'name': '王建中'},
#   {'authorId': '80068024', 'name': '蔡晓东'},
#   {'authorId': '66486956', 'name': '丁建军'},
#   {'authorId': '81021948', 'name': '李维平'},
#   {'authorId': '1474054841', 'name': '付友增'},
#   {'authorId': '1475846842', 'name': '陈耕野'},
#   {'authorId': '1996397447', 'name': '肖邦良'},
#   {'authorId': '66480329', 'name': '毛伯镛'},
#   {'authorId': '69408990', 'name': '罗宏'},
#   {'authorId': '83269768', 'name': '张文燕'}],
#  'venue': '',
#  'publicationvenueid': None,
#  'year': 2002,
#  'referencecount': 0,
#  'citationcount': 0,
#  'influentialcitationcount': 0,
#  'isopenaccess': False,
#  's2fieldsofstudy': None,
#  'publicationtypes': None,
#  'publicationdate': None,
#  'journal': {'name': '', 'pages': '165-167', 'volume': '7'},
#  'updated': '2022-01-27T10:59:03.668Z'}

# %%
# get embeddings
from typing import Dict, List
import json
import requests

URL = "https://model-apis.semanticscholar.org/specter/v1/invoke"
MAX_BATCH_SIZE = 16

def chunks(lst, chunk_size=MAX_BATCH_SIZE):
    """Splits a longer list to respect batch size"""
    for i in range(0, len(lst), chunk_size):
        yield lst[i : i + chunk_size]


# SAMPLE_PAPERS = [
#     {
#         "paper_id": "A",
#         "title": "Angiotensin-converting enzyme 2 is a functional receptor for the SARS coronavirus",
#         "abstract": "Spike (S) proteins of coronaviruses ...",
#     },
#     {
#         "paper_id": "B",
#         "title": "Hospital outbreak of Middle East respiratory syndrome coronavirus",
#         "abstract": "Between April 1 and May 23, 2013, a total of 23 cases of MERS-CoV ...",
#     },
# ]


def embed(papers):
    embeddings_by_paper_id: Dict[str, List[float]] = {}

    for chunk in chunks(papers):
        # Allow Python requests to convert the data above to JSON
        # print(chunk)
        response = requests.post(URL, json=chunk)

        if response.status_code != 200:
            raise RuntimeError("Sorry, something went wrong, please try later!")

        for paper in response.json()["preds"]:
            embeddings_by_paper_id[paper["paper_id"]] = paper["embedding"]

    return embeddings_by_paper_id

# if __name__ == "__main__":
#     all_embeddings = embed(SAMPLE_PAPERS)

#     # Prints { 'A': [4.089589595794678, ...], 'B': [-0.15814849734306335, ...] }
#     print(all_embeddings)

# %%
URL = "https://model-apis.semanticscholar.org/specter/v1/invoke"
MAX_BATCH_SIZE = 16

def chunks(lst, chunk_size=MAX_BATCH_SIZE):
    """Splits a longer list to respect batch size"""
    for i in range(0, len(lst), chunk_size):
        yield lst[i : i + chunk_size]

# %%
papers[0]
# Out:
# {'corpusid': 209821356,
#  'externalids': {'ACL': None,
#   'DBLP': None,
#   'ArXiv': None,
#   'MAG': '885611991',
#   'CorpusId': '209821356',
#   'PubMed': None,
#   'DOI': None,
#   'PubMedCentral': None},
#  'url': 'https://www.semanticscholar.org/paper/a12266fce7d3b22b5a4c9cac9c7a3675f9cc1f46',
#  'title': '星形细胞瘤热休克蛋白70（HSP70）表达的研究',
#  'authors': [{'authorId': '66573337', 'name': '王建中'},
#   {'authorId': '80068024', 'name': '蔡晓东'},
#   {'authorId': '66486956', 'name': '丁建军'},
#   {'authorId': '81021948', 'name': '李维平'},
#   {'authorId': '1474054841', 'name': '付友增'},
#   {'authorId': '1475846842', 'name': '陈耕野'},
#   {'authorId': '1996397447', 'name': '肖邦良'},
#   {'authorId': '66480329', 'name': '毛伯镛'},
#   {'authorId': '69408990', 'name': '罗宏'},
#   {'authorId': '83269768', 'name': '张文燕'}],
#  'venue': '',
#  'publicationvenueid': None,
#  'year': 2002,
#  'referencecount': 0,
#  'citationcount': 0,
#  'influentialcitationcount': 0,
#  'isopenaccess': False,
#  's2fieldsofstudy': None,
#  'publicationtypes': None,
#  'publicationdate': None,
#  'journal': {'name': '', 'pages': '165-167', 'volume': '7'},
#  'updated': '2022-01-27T10:59:03.668Z'}

# %%
response = requests.post(URL, json=papers[0:10])
response
# Out:
# <Response [502]>

# %%
for chunk in chunks(papers[0]):
    # print(chunk)
    response = requests.post(URL, json=chunk)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 for chunk in chunks(papers[0]):
#       2     # print(chunk)
#       3     response = requests.post(URL, json=chunk)
#
# Cell In[55], line 7, in chunks(lst, chunk_size)
#       5 """Splits a longer list to respect batch size"""
#       6 for i in range(0, len(lst), chunk_size):
# ----> 7     yield lst[i : i + chunk_size]
#
# TypeError: unhashable type: 'slice'

# %%
response
# Out:
# <Response [502]>

# %%
papers
# Out:
# [{'corpusid': 209821356,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '885611991',
#    'CorpusId': '209821356',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/a12266fce7d3b22b5a4c9cac9c7a3675f9cc1f46',
#   'title': '星形细胞瘤热休克蛋白70（HSP70）表达的研究',
#   'authors': [{'authorId': '66573337', 'name': '王建中'},
#    {'authorId': '80068024', 'name': '蔡晓东'},
#    {'authorId': '66486956', 'name': '丁建军'},
#    {'authorId': '81021948', 'name': '李维平'},
#    {'authorId': '1474054841', 'name': '付友增'},
#    {'authorId': '1475846842', 'name': '陈耕野'},
#    {'authorId': '1996397447', 'name': '肖邦良'},
#    {'authorId': '66480329', 'name': '毛伯镛'},
#    {'authorId': '69408990', 'name': '罗宏'},
#    {'authorId': '83269768', 'name': '张文燕'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2002,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': '165-167', 'volume': '7'},
#   'updated': '2022-01-27T10:59:03.668Z'},
#  {'corpusid': 230732139,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2205493012',
#    'CorpusId': '230732139',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/be5a5156402d6fc632977f48ba46621196c642e1',
#   'title': 'Années 2009 à 2014',
#   'authors': [{'authorId': '52049503', 'name': 'Dreal Limousin'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2015,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': '2015-10-23',
#   'journal': {'name': '', 'pages': None, 'volume': ''},
#   'updated': '2022-01-27T13:19:23.917Z'},
#  {'corpusid': 118105413,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '379921969',
#    'CorpusId': '118105413',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/022f1585041bbe99bb9ab26d6b379353ae3ad15e',
#   'title': 'Self-organization of isotopic and drift-ware turbulence',
#   'authors': [{'authorId': '93856515', 'name': 'A. Pushkarev'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2013,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': [{'category': 'Physics', 'source': 's2-fos-model'},
#    {'category': 'Physics', 'source': 'external'}],
#   'publicationtypes': None,
#   'publicationdate': '2013-12-18',
#   'journal': None,
#   'updated': '2022-01-27T17:31:22.629Z'},
#  {'corpusid': 179785784,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '1467144693',
#    'CorpusId': '179785784',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/050a41063600357d2be253077b9833bb30388a3e',
#   'title': 'Математические модели формирования спортивных групп',
#   'authors': [{'authorId': '135047190',
#     'name': 'Тамара Александровна Воротова'},
#    {'authorId': '134997271', 'name': 'Ксения Игоревна Сыромолотова'},
#    {'authorId': '134955869', 'name': 'Виктория Александровна Крылова'},
#    {'authorId': '78426911', 'name': 'Евгений Петрович Колпак'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2015,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': '10-19', 'volume': ''},
#   'updated': '2022-02-08T13:49:34.261Z'},
#  {'corpusid': 178548189,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '1507902412',
#    'CorpusId': '178548189',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/c2ebd66d7b13b8a03c423c9d476dc56cc6287ad6',
#   'title': 'La informatización de la Tesorería y (II)',
#   'authors': [{'authorId': '69015198', 'name': 'Miguel Torán Torrescassana'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 1992,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': None,
#   'updated': '2022-02-08T14:20:37.725Z'},
#  {'corpusid': 178438813,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '1536047356',
#    'CorpusId': '178438813',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/477bec02c90664cca8da0d3caa5c8c98a416d844',
#   'title': '神似 “天网”的KFW防火墙',
#   'authors': [{'authorId': '136426644', 'name': '舒洁'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2003,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': None,
#   'updated': '2022-02-08T14:23:39.063Z'},
#  {'corpusid': 178273625,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '1814368796',
#    'CorpusId': '178273625',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/14338a006dd230bf2ecb56ee0bceb7843353ef62',
#   'title': 'بررسی شرایط مناسب برشته کردن برای جلوگیری از اکسیداسیون روغن فندق و بادام زمینی',
#   'authors': [{'authorId': '135086186', 'name': 'رامین رادفر'},
#    {'authorId': '97019460', 'name': 'حسن فاطمی'},
#    {'authorId': '88858573', 'name': 'محمدعلی سحری'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2003,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': None,
#   'updated': '2022-02-08T14:27:37.658Z'},
#  {'corpusid': 178127993,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2172890454',
#    'CorpusId': '178127993',
#    'PubMed': None,
#    'DOI': '10.18094/SI.98803',
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/a1e42747795f5101a83aa5ba394c4700bf731ba5',
#   'title': 'İletişim Doyumu Boyutları İle Örgütlenme Yapısı İlişkisi: Selçuk Üniversitesi Akademisyenleri Örneği',
#   'authors': [{'authorId': '71363008', 'name': 'Birol Gülnar'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2009,
#   'referencecount': 7,
#   'citationcount': 3,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': '62-82', 'volume': '5'},
#   'updated': '2022-02-08T14:30:48.424Z'},
#  {'corpusid': 177610881,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '643616573',
#    'CorpusId': '177610881',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/7e55bbd8729efe6b597675dfd9137a35bb2aaa36',
#   'title': 'Zen, oder, Die Kunst der Präsentation : mit einfachen Ideen gestalten und präsentieren',
#   'authors': [{'authorId': '2053637673', 'name': 'Garr Reynolds'},
#    {'authorId': '122452892', 'name': 'Christoph Kommer'},
#    {'authorId': '71621257', 'name': 'Isolde Kommer'},
#    {'authorId': '2084300870', 'name': 'Guy Kawasaki'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2012,
#   'referencecount': 0,
#   'citationcount': 3,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': None, 'volume': ''},
#   'updated': '2022-02-08T14:42:04.959Z'},
#  {'corpusid': 177548331,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '786998118',
#    'CorpusId': '177548331',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/4fec6a36c95a7ae5615608686cd98009e460b0ac',
#   'title': 'Participación Simultánea de las interacciones de Puente de Hidrógeno, Polares y Dispersivas en la Formación de Agregados de Asfaltenos.',
#   'authors': [{'authorId': '2070808707', 'name': 'Sócrates Acevedo'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2012,
#   'referencecount': 17,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': '7-15', 'volume': '19'},
#   'updated': '2022-02-08T14:44:41.301Z'},
#  {'corpusid': 176605171,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '881217921',
#    'CorpusId': '176605171',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/1e279614971918f4c31898915c7a2bfc7c8bc387',
#   'title': '美眼看世界 美心感世界——美育课堂上人文素质培养的实践与探讨',
#   'authors': [{'authorId': '135991015', 'name': '杨卫丽'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2012,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': None,
#   'updated': '2022-02-08T15:23:25.684Z'},
#  {'corpusid': 176591518,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '631314731',
#    'CorpusId': '176591518',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/766551fc1855cfc55019dc333212cb90812b9548',
#   'title': '一所懸命に求め続けた成果が感動を呼んだ (第一特集 ほんとうのサービスとは何か)',
#   'authors': [{'authorId': '91610689', 'name': '宮脇 修'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2003,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': '30-33', 'volume': ''},
#   'updated': '2022-02-08T15:23:26.434Z'},
#  {'corpusid': 176238132,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '392342475',
#    'CorpusId': '176238132',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/66d169f1ed09c03665f7bc11d6318eacdc7bd3a1',
#   'title': '座談会 阪神・淡路大震災から5年を経て、そして未来へ (特集 阪神・淡路大震災から5年)',
#   'authors': [{'authorId': '96109037', 'name': '黒田 勝彦'},
#    {'authorId': '136615281', 'name': '金澤 寛'},
#    {'authorId': '89348508', 'name': '山本 信行'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2000,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': None,
#   'updated': '2022-02-08T15:27:16.584Z'},
#  {'corpusid': 175006182,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '391781849',
#    'CorpusId': '175006182',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/f7ddb2f25865b2b1d384afb4e6d1e2aedbeb375c',
#   'title': '6015 阪神・淡路大震災における都市-農村関係からみた救援・復興過程 : 北区「八多ふれあいセンター」事例に(農村計画)',
#   'authors': [{'authorId': '87406304', 'name': '西田 和美'},
#    {'authorId': '88447600', 'name': '重村 力'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 1999,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': None,
#   'updated': '2022-02-08T15:37:41.092Z'},
#  {'corpusid': 173846162,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '260164522',
#    'CorpusId': '173846162',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/75e8807b4a0a43efeeff173c1f649db0fbff7380',
#   'title': 'Directoras. Cómo dirigir sin morir en el intento',
#   'authors': [{'authorId': '143984657', 'name': 'M. Casanova'},
#    {'authorId': '2070735576', 'name': 'J. Angulo'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2003,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': '144-147', 'volume': ''},
#   'updated': '2022-02-08T15:54:09.815Z'},
#  {'corpusid': 172732545,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '109015263',
#    'CorpusId': '172732545',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/cf325290160df3d723b438a8d46628a780767e0e',
#   'title': 'Episcopato, clero e società a Chieti in età moderna',
#   'authors': [{'authorId': '65751166', 'name': 'A. Tanturri'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2004,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': '1-239', 'volume': ''},
#   'updated': '2022-02-08T16:15:14.753Z'},
#  {'corpusid': 171413397,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2938760023',
#    'CorpusId': '171413397',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/3dcd8ab853c3e36f2f0cd1fadfbc3df5eb001f50',
#   'title': 'Vivir con honor o con honor morir. La reelaboración de una disyuntiva heroica en el Heracles de Eurípides',
#   'authors': [{'authorId': '145185719', 'name': 'M. Reguero'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2019,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': [{'category': 'Psychology', 'source': 's2-fos-model'},
#    {'category': 'Philosophy', 'source': 'external'}],
#   'publicationtypes': None,
#   'publicationdate': '2019-04-01',
#   'journal': {'name': 'Agora-estudos Classicos Em Debate',
#    'pages': '83-102',
#    'volume': ''},
#   'updated': '2022-02-08T16:50:50.711Z'},
#  {'corpusid': 184758404,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2595492405',
#    'CorpusId': '184758404',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/1171fa9fb02b140c949355da2f3ec1e9914f0f15',
#   'title': '【デキる師長になるためのセカンドステップ 数字脳×経営脳超トレーニング】 出世なんてしたくない？ 中間管理職の苦悩',
#   'authors': [{'authorId': '136444170', 'name': '英洙 裵'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2016,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': '502-505', 'volume': '10'},
#   'updated': '2022-02-08T11:46:25.782Z'},
#  {'corpusid': 184495033,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2604407533',
#    'CorpusId': '184495033',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/56378658ca0dafaf792e7c168b0799a73530b60b',
#   'title': 'Vergleich von vier kommerziellen Futtersorten bei der Aufzucht von Glasaalen',
#   'authors': [{'authorId': '87556352', 'name': 'H. Kuhlmann'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 1991,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': None, 'volume': ''},
#   'updated': '2022-02-08T11:53:52.720Z'},
#  {'corpusid': 184668873,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2578064179',
#    'CorpusId': '184668873',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/9c4dce292ad917998ed458bd01aca7a609605199',
#   'title': 'Persepsi Ibubapa Dan Murid Tahun 4 Dan 5 Terhadap Pembelajaran Abad Ke 21: Satu Kajian Kes',
#   'authors': [{'authorId': '144276101', 'name': 'Halif Md Saleh'},
#    {'authorId': '6629358', 'name': 'Ramlee Mustapha'},
#    {'authorId': '103520499', 'name': 'Zamani Ibrahim'},
#    {'authorId': '2073926437', 'name': 'Malaysia'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2015,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': None, 'volume': '502'},
#   'updated': '2022-02-08T11:48:56.764Z'},
#  {'corpusid': 184665916,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2530543330',
#    'CorpusId': '184665916',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/7b7bd67b355faa6b8578f0c9a229f4f829eb66ff',
#   'title': 'Einfluss der Holzschliffbeschaffenheit auf Opazität und auf Durchscheinen und Durchdringen von Druckfarbe in Papier',
#   'authors': [{'authorId': '47940750', 'name': 'W. Brecht'},
#    {'authorId': '146714709', 'name': 'F. Holzhey'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 1968,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': None, 'volume': ''},
#   'updated': '2022-02-08T11:48:57.738Z'},
#  {'corpusid': 185030560,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2550436920',
#    'CorpusId': '185030560',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/62261d20d5c87ccb4960cad5f829d5e5865a9eb6',
#   'title': '윤리적인 측면에서 본 안락사(安樂死) 연구',
#   'authors': [{'authorId': '52578841', 'name': '조은숙'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 1983,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': '163-179', 'volume': '4'},
#   'updated': '2022-02-08T11:39:11.394Z'},
#  {'corpusid': 184864068,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2612262224',
#    'CorpusId': '184864068',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/f29252c45af92656e1e9d5912c6f91259c591da0',
#   'title': 'Il trono di sole. Panegirico di Francesco Amedeo Ormea per Amedeo IX di Savoia',
#   'authors': [{'authorId': '121730642', 'name': 'Luisella Giachino'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2013,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': None,
#   'updated': '2022-02-08T11:44:04.560Z'},
#  {'corpusid': 182973288,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2493422794',
#    'CorpusId': '182973288',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/e908040ea11a5ff27edf2b15ac438218c013ed7e',
#   'title': '深化能源合作 实现互利共赢——第三届中阿能源合作大会开幕',
#   'authors': [{'authorId': '149364175', 'name': '钟培源'},
#    {'authorId': '148967626', 'name': '勉晓萌'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2012,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': None,
#   'updated': '2022-02-08T12:36:18.605Z'},
#  {'corpusid': 181146937,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2274843850',
#    'CorpusId': '181146937',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/0ca82faa7df905dd941c253c4e6989e3431ed4be',
#   'title': '基于 ANSYS 巷道掘进支护平台支撑臂强度分析',
#   'authors': [{'authorId': '2102849330', 'name': '马齐江'},
#    {'authorId': '2060074272', 'name': '陈凯'},
#    {'authorId': '2102747432', 'name': '王开松'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2014,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': '89-90', 'volume': '35'},
#   'updated': '2022-02-08T13:16:33.830Z'},
#  {'corpusid': 181482451,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '585326300',
#    'CorpusId': '181482451',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/c6466d4db9592548b9aeda8bc813a273078d0b48',
#   'title': '地方交付税の役割と課題をきく (「地域格差」再考 )',
#   'authors': [{'authorId': '52275061', 'name': '高橋 誠'},
#    {'authorId': '119410182', 'name': '寄本 勝美'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 1985,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': None,
#   'updated': '2022-02-08T13:14:32.909Z'},
#  {'corpusid': 180531050,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2288559416',
#    'CorpusId': '180531050',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/72d285a58c9e0ca969e7309bbd123ead3827ab1c',
#   'title': "P. Guichonnet, Cavour agrononomo e uomo d'affari.",
#   'authors': [{'authorId': '2086443611', 'name': 'J. Hémardinquer'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 1964,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': '414-414', 'volume': '19'},
#   'updated': '2022-02-08T13:27:21.791Z'},
#  {'corpusid': 180088753,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '1173209344',
#    'CorpusId': '180088753',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/76ee00716a6361cadb42bafcf7b82d2d3496c5c2',
#   'title': '坚持“以人为本” 促进和谐社会的构建',
#   'authors': [{'authorId': '108469251', 'name': '陈福川'},
#    {'authorId': '135348330', 'name': '何君陆'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2005,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': None,
#   'updated': '2022-02-08T13:39:55.596Z'},
#  {'corpusid': 180438284,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2297616676',
#    'CorpusId': '180438284',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/ea3f49f9469820d5a68976ac654033413e82f800',
#   'title': 'つぶやきノートから、子どものこころを垣間見る : 他者とかかわる子どものこころの発達 (特集 他者のこころの理解と発達)',
#   'authors': [{'authorId': '119776207', 'name': '中丸 元良'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2015,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': '70-75', 'volume': '36'},
#   'updated': '2022-02-08T13:30:17.948Z'},
#  {'corpusid': 172123782,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2896923424',
#    'CorpusId': '172123782',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/332167a10aefdbca2561605dfec342bcb27a868a',
#   'title': 'Principios filosóficos del marxismo: Conferencia en conmemoración de los cien años de la muerte de Karl Marx. 13 de abril de 1983. Facultad de Filosofía y Letras de la Universidad de Oviedo',
#   'authors': [{'authorId': '144923638', 'name': 'G. Bueno'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2017,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': '99-109', 'volume': ''},
#   'updated': '2022-02-08T16:28:58.442Z'},
#  {'corpusid': 171982973,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2886813646',
#    'CorpusId': '171982973',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/0109d4376f3ab2d96d1af1262a6e10f85645a765',
#   'title': 'Anordnung mit einem strömungsgleichrichter',
#   'authors': [{'authorId': '46680874', 'name': 'U. Stahl'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2015,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': '2015-04-13',
#   'journal': {'name': '', 'pages': None, 'volume': ''},
#   'updated': '2022-02-08T16:33:32.680Z'},
#  {'corpusid': 168899273,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2776654442',
#    'CorpusId': '168899273',
#    'PubMed': None,
#    'DOI': '10.4172/2162-6359.1000469',
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/649ed1665082047a548e883185bdcc70f0d4791e',
#   'title': 'A Study on Comparative Analysis of Impact of Soft Skill Training on the Employees of Private and Public Sector Banks in the City of Belgaum, Karnataka',
#   'authors': [{'authorId': '152904192', 'name': 'S. Deshpande'},
#    {'authorId': '115877950', 'name': 'M. M. Munshi'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2017,
#   'referencecount': 0,
#   'citationcount': 1,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': [{'category': 'Business', 'source': 's2-fos-model'},
#    {'category': 'Economics', 'source': 'external'}],
#   'publicationtypes': None,
#   'publicationdate': '2017-10-18',
#   'journal': {'name': 'International Journal of Economics and Management Sciences',
#    'pages': '1-5',
#    'volume': '6'},
#   'updated': '2022-02-08T18:07:26.499Z'},
#  {'corpusid': 168648931,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2762731546',
#    'CorpusId': '168648931',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/f9ebc60d531ef467f98e3b42a8e983e3b265e218',
#   'title': 'PERTANGGUNGJAWABAN HUKUM TERHADAP PENYIMPANGAN PENGADAAN BARANG/JASA PEMERINTAH OLEH PEJABAT PEMBUAT KOMITMEN (PPK)',
#   'authors': [{'authorId': '107867217', 'name': 'A. DickyArganova'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2017,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': '2017-08-22',
#   'journal': {'name': '', 'pages': None, 'volume': ''},
#   'updated': '2022-02-08T18:14:56.570Z'},
#  {'corpusid': 167310487,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2053815104',
#    'CorpusId': '167310487',
#    'PubMed': None,
#    'DOI': '10.1300/J054V06N01_06',
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/ed7413f185481796324d0eee2c2cd812ca05d522',
#   'title': 'Using “Best Practices” to Construct a Pro Forma Marketing Plan for Early Childhood Intervention Services',
#   'authors': [{'authorId': '37864054', 'name': 'D. Fugate'},
#    {'authorId': '117847271', 'name': 'Janet M. Fugate'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 1998,
#   'referencecount': 3,
#   'citationcount': 1,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': [{'category': 'Medicine', 'source': 's2-fos-model'},
#    {'category': 'Business', 'source': 'external'}],
#   'publicationtypes': None,
#   'publicationdate': '1998-08-19',
#   'journal': {'name': 'Journal of Nonprofit & Public Sector Marketing',
#    'pages': '83-96',
#    'volume': '6'},
#   'updated': '2022-02-08T19:02:50.392Z'},
#  {'corpusid': 167385230,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2262313694',
#    'CorpusId': '167385230',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/93d1111b6bec640fb35614dc5570aedc32a9aef1',
#   'title': '기업 소유ㆍ지배괴리도가 대리인 비용에 미치는 영향',
#   'authors': [{'authorId': '80327759', 'name': '김지혜'},
#    {'authorId': '65985939', 'name': '이상욱'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2012,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': [{'category': 'Physics', 'source': 's2-fos-model'},
#    {'category': 'Business', 'source': 'external'}],
#   'publicationtypes': None,
#   'publicationdate': '2012-04-01',
#   'journal': None,
#   'updated': '2022-02-08T19:00:22.605Z'},
#  {'corpusid': 167294317,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2381410269',
#    'CorpusId': '167294317',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/f0b1a7ed046ace100087cc68994b350a76151f9e',
#   'title': 'Design of Personnel Organization Management System',
#   'authors': [{'authorId': '2116465375', 'name': 'Yu Yang'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2009,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': [{'category': 'Business', 'source': 's2-fos-model'},
#    {'category': 'Computer Science', 'source': 'external'}],
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': 'Computer Knowledge and Technology',
#    'pages': None,
#    'volume': ''},
#   'updated': '2022-02-08T19:03:27.266Z'},
#  {'corpusid': 165701177,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2895992093',
#    'CorpusId': '165701177',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/beecbb5613cbacf482ce504b90b39676d5a8f4df',
#   'title': 'Vollsmoseindsatsens organisering: et område - mange aktører',
#   'authors': [{'authorId': '2074646834', 'name': 'Jørgen Anker'},
#    {'authorId': '118992977', 'name': 'I. Christensen'},
#    {'authorId': '2085744650', 'name': 'I. Koch-Nielsen'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2003,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': None,
#   'updated': '2022-02-08T19:49:44.396Z'},
#  {'corpusid': 194110024,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2180446944',
#    'CorpusId': '194110024',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/cba5e250835377ba2d4ac62f1be77e113a74654d',
#   'title': 'The Baroque, the grotesque, and social criticism in the Buscon and La Hora de Todos of Quevedo: El Barroco, lo grotesco, y la critica social en el Buscon y La Hora de Todos de Quevedo',
#   'authors': [{'authorId': '46694373', 'name': 'N. Carrero'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 1993,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': None, 'volume': ''},
#   'updated': '2022-02-08T08:17:24.314Z'},
#  {'corpusid': 193368889,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '373194569',
#    'CorpusId': '193368889',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/5ad37893e3fbd570cf8a2ba74573b3d7f21b257f',
#   'title': 'Victor Hugo et la Bible',
#   'authors': [{'authorId': '69368718', 'name': 'H. Meschonnic'},
#    {'authorId': '115980250', 'name': 'M. Ôno'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2001,
#   'referencecount': 0,
#   'citationcount': 1,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': None, 'volume': ''},
#   'updated': '2022-02-08T08:24:08.614Z'},
#  {'corpusid': 192849303,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2626151503',
#    'CorpusId': '192849303',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/c95868f7331483933798c0997dd5e33ca4459b87',
#   'title': 'Envoi de deux députés auprès du Roi, lors de la séance du 6 octobre 1789',
#   'authors': [{'authorId': '119627650', 'name': 'J. Mounier'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': None,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': '349-349', 'volume': '9'},
#   'updated': '2022-02-08T08:38:10.156Z'},
#  {'corpusid': 192722588,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2901564075',
#    'CorpusId': '192722588',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/215a728ed382318da4d519efd8fe696da2604d13',
#   'title': 'AUTONOMIZAÇÃO DO CAMPO ARTÍSTICO E SINGULARIZAÇÃO DA EXPERIÊNCIA ESTÉTICA: A INSTITUIÇÃO DO LUGAR SOCIAL DA ARTE E DO ARTISTA EM FORTALEZA',
#   'authors': [{'authorId': '113956597', 'name': 'Kadma Marques'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2018,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': [{'category': 'Art', 'source': 's2-fos-model'},
#    {'category': 'Art', 'source': 'external'}],
#   'publicationtypes': None,
#   'publicationdate': '2018-08-24',
#   'journal': {'name': '', 'pages': '30-52', 'volume': '38'},
#   'updated': '2022-02-08T08:41:30.626Z'},
#  {'corpusid': 204321286,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '1983392382',
#    'CorpusId': '204321286',
#    'PubMed': None,
#    'DOI': '10.1111/j.1600-0447.1946.tb07279.x',
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/9a187210461f70f48d96eb6bd4de96c3ae78f3cf',
#   'title': 'EARLY DIFFERENTIAL DIAGNOSIS BETWEEN PSYCHOGENIC PSYCHOSIS AND SCHIZOPHRENIA',
#   'authors': [{'authorId': '114790134', 'name': 'Poul M. Færgeman'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 1946,
#   'referencecount': 1,
#   'citationcount': 7,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': [{'category': 'Psychology', 'source': 's2-fos-model'},
#    {'category': 'Medicine', 'source': 's2-fos-model'},
#    {'category': 'Psychology', 'source': 'external'}],
#   'publicationtypes': None,
#   'publicationdate': '1946-09-01',
#   'journal': {'name': 'Acta Psychiatrica Scandinavica',
#    'pages': None,
#    'volume': '21'},
#   'updated': '2022-02-08T09:12:19.910Z'},
#  {'corpusid': 186153071,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2578497897',
#    'CorpusId': '186153071',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/8a15b89d716cb735a264291a8f07af8017d64ce6',
#   'title': 'Beskrivelse af iltsvindsmodellen DOSMO',
#   'authors': [{'authorId': '1403839490', 'name': 'Kjeld Schaarup-Jensen'},
#    {'authorId': '2093346087', 'name': 'Thorkild Hvitved-Jacobsen'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 1991,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': None, 'volume': ''},
#   'updated': '2022-02-08T11:11:44.980Z'},
#  {'corpusid': 194584694,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2761122932',
#    'CorpusId': '194584694',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/f95aeafb7691ddd8b5fa0dc1a2c40ea65e82e2e4',
#   'title': 'Communisten, commercie en de COCOM. De overwegingen van de Nederlandse regering met betrekking tot controles op de export naar het Oostblok (1948-1952).',
#   'authors': [{'authorId': '2103448028', 'name': 'W. R. Berkhof'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2017,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': None, 'volume': ''},
#   'updated': '2022-02-08T08:13:24.631Z'},
#  {'corpusid': 193700389,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2592300726',
#    'CorpusId': '193700389',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/edaafab9aaf9a4bd0b834b387c1f83a25bca55f9',
#   'title': 'L’edificio sacro e la città. Complesso parrocchiale di San Carlo Borromeo a Roma',
#   'authors': [{'authorId': '69401474', 'name': 'A. Monestiroli'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2006,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': None,
#   'updated': '2022-02-08T08:19:37.339Z'},
#  {'corpusid': 193867946,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2596571190',
#    'CorpusId': '193867946',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/c33eff0036adcff56e5f48aa77c366a481142559',
#   'title': 'EROSÃO E DEPOSIÇÃO NO LIMITE DA COSTA DO REBOJÃO COM A COSTA DA TERRA NOVA, ILHA DO CAREIRO-AM, E AS MANIFESTAÇÕES NA ORGANIZAÇÃO DO ESPAÇO',
#   'authors': [{'authorId': '147336041', 'name': 'L. Maia'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2015,
#   'referencecount': 9,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': '2015-07-31',
#   'journal': {'name': '', 'pages': None, 'volume': ''},
#   'updated': '2022-02-08T08:19:19.772Z'},
#  {'corpusid': 193646365,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2560879310',
#    'CorpusId': '193646365',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/4dcc469fc4ca08d56021e53237b3e50b70415f7f',
#   'title': 'Vánoce v preprimárním vzdělávání',
#   'authors': [{'authorId': '146265945', 'name': 'Blanka Helešicová'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2014,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': None, 'volume': ''},
#   'updated': '2022-02-08T08:21:10.969Z'},
#  {'corpusid': 190875536,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '588168760',
#    'CorpusId': '190875536',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/530255d50b57357507aa9f923692c0746a365a57',
#   'title': "Corso normale degli institutori primarii, ossia, Direzioni relative all'educazione fisica morale e intellettuale",
#   'authors': [{'authorId': '147070466',
#     'name': 'Joseph-Marie baron de Gérando'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': None,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': None, 'volume': ''},
#   'updated': '2022-02-08T09:12:25.907Z'},
#  {'corpusid': 190079491,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '238407800',
#    'CorpusId': '190079491',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/2140eaf5a042f1808c2e17d8b4aa390194644bdb',
#   'title': 'ANALISIS DAN PERANCANGAN E-PROCUREMENT PADA PT. INDO JAYA KERTAS',
#   'authors': [{'authorId': '49111993', 'name': 'H. Hartono'},
#    {'authorId': '69064215', 'name': 'S.Kom. Mm Henry Antonius Eka W'},
#    {'authorId': '69327212', 'name': 'S. Dewanti'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2013,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': None,
#   'updated': '2022-02-08T09:35:05.369Z'},
#  {'corpusid': 190127498,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '1485277564',
#    'CorpusId': '190127498',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/b58dffcd0ef5bcce5ae976ee0f16ce947120a7a1',
#   'title': 'Proporción divina en pacientes con síndrome de clase II división 1',
#   'authors': [{'authorId': '82015514', 'name': 'Yaíma Lazo Amador'},
#    {'authorId': '80726390', 'name': 'G. Laffitte'},
#    {'authorId': '13577548', 'name': 'G. M. Manso'},
#    {'authorId': '47561995', 'name': 'Á. Rojas'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2012,
#   'referencecount': 22,
#   'citationcount': 1,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': '2012-04-20',
#   'journal': {'name': '', 'pages': '117-127', 'volume': '49'},
#   'updated': '2022-02-08T09:33:49.686Z'},
#  {'corpusid': 189293175,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2904205304',
#    'CorpusId': '189293175',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/59961fcd2e4363e7c38a0faf7e4ab5674c51ed6e',
#   'title': 'Note sur la question 403 (voir p. 117)',
#   'authors': [{'authorId': '147779240', 'name': 'P. Challiot'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': None,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': '191-192', 'volume': '17'},
#   'updated': '2022-02-08T09:55:29.218Z'},
#  {'corpusid': 188596657,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '40583600',
#    'CorpusId': '188596657',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/e989b63ed007f5eebd21ccf7ca650cc77bd8b521',
#   'title': "PENERAPAN MODEL PEMBELAJARAN KOOPERATIF TIPE JIGSAW UNTUK MENINGKATKAN HASIL BELAJAR FIKIH KELAS IV MATERI POKOK INFAK DAN SEDEKAH DI MI MIFTAHUL MUBTADI'IN DABUNG BANGKALAN",
#   'authors': [{'authorId': '2070505384', 'name': 'Qurrotul Aini'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2013,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': None, 'volume': ''},
#   'updated': '2022-02-08T10:12:10.601Z'},
#  {'corpusid': 188509702,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2741807414',
#    'CorpusId': '188509702',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/03ab5bd523be50a39745212891a1d3104b8b9c9f',
#   'title': 'Categorie protette - rapporti di lavoro speciali',
#   'authors': [{'authorId': '73042136', 'name': 'De Leo'},
#    {'authorId': '120007498', 'name': 'Giada Emanuela'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2012,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': '317-374', 'volume': ''},
#   'updated': '2022-02-08T10:15:14.898Z'},
#  {'corpusid': 188227478,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2902843723',
#    'CorpusId': '188227478',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/0dcf5ceb34bf0de525be2105c0cf706c9ec65689',
#   'title': 'El momento, la decisión, el objetivo',
#   'authors': [{'authorId': '52025739', 'name': 'A. Olmeda'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2018,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': '1', 'volume': ''},
#   'updated': '2022-02-08T10:23:09.089Z'},
#  {'corpusid': 188300936,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2807854711',
#    'CorpusId': '188300936',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/ad3ab3306bafc9f3aa4ad39e7367e3dca289dc4b',
#   'title': 'Les effets des féminismes',
#   'authors': [{'authorId': '13169004', 'name': 'Alban Jacquemart'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2012,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': None,
#   'updated': '2022-02-08T10:22:30.131Z'},
#  {'corpusid': 187202329,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '4293890',
#    'CorpusId': '187202329',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/133d6b2f181ddd957989fea3c0dbb24a5fb784c8',
#   'title': 'Historia gráfica del CAF (la colección)',
#   'authors': [{'authorId': '2054063911', 'name': 'C. Marín'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2007,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': None,
#   'updated': '2022-02-08T10:45:30.935Z'},
#  {'corpusid': 185659969,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2513719319',
#    'CorpusId': '185659969',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/2817cf1878417e6b63703b3353ad91c03a77e81c',
#   'title': 'Técnica para retirada de cabos-eletrodos endocárdicos antigos',
#   'authors': [{'authorId': '48552908', 'name': 'Celso Salgado de Melo'},
#    {'authorId': '133674589', 'name': 'Aldo Alér Tomas'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 1989,
#   'referencecount': 6,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': '93-97', 'volume': '2'},
# ...
#   'publicationdate': '2020-06-14',
#   'journal': {'name': '', 'pages': '23-30', 'volume': '2'},
#   'updated': '2022-02-08T00:05:57.806Z'},
#  {'corpusid': 224593816,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '820057617',
#    'CorpusId': '224593816',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/dd5492da9970c9c2e7084c6f640afa4e247729d0',
#   'title': '舛误与僭越：青年卢卡奇的阶级意识剖论——历史唯物主义规律观评述',
#   'authors': [{'authorId': '89245810', 'name': '吴小宁'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2000,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': '83-91', 'volume': ''},
#   'updated': '2022-02-08T00:23:10.669Z'},
#  {'corpusid': 224608191,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2754261914',
#    'CorpusId': '224608191',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/d2ad56c8a4500b3aa3c2f2b8e834efffee7920dc',
#   'title': '3Gネットワークロボットプラットフォームに基づく研究と設計【JST・京大機械翻訳】',
#   'authors': [{'authorId': '2002711858', 'name': 'Wu Yongzhuo'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2012,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': '101', 'volume': '34'},
#   'updated': '2022-02-08T00:22:03.161Z'},
#  {'corpusid': 222453585,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '3005113296',
#    'CorpusId': '222453585',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/09ecf61abfd3a98bb60d7e872f32f9a81d3e5798',
#   'title': 'Tissue ablation method using protruding electrosurgical electrodes',
#   'authors': [{'authorId': '1483956740', 'name': 'エガーズ、アンドリュー・アール'},
#    {'authorId': '1483949972', 'name': 'エガーズ、エリック・エイ'},
#    {'authorId': '1483956028', 'name': 'エガーズ、フィリップ・イー'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2000,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': [{'category': 'Medicine', 'source': 's2-fos-model'},
#    {'category': 'Materials Science', 'source': 'external'}],
#   'publicationtypes': None,
#   'publicationdate': '2000-10-10',
#   'journal': {'name': '', 'pages': None, 'volume': ''},
#   'updated': '2022-02-08T00:52:33.684Z'},
#  {'corpusid': 209513529,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': None,
#    'CorpusId': '209513529',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/477dfac37c65ad7f45aefb5412a619496b9770ca',
#   'title': 'RELIABILITY ASSESMENT AND MANAGEMENT OF COOLANT FLOW MEASURE SYSTEM IN RBMK-1500 REACTOR',
#   'authors': [{'authorId': '2337548', 'name': 'V. Matuzas'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2003,
#   'referencecount': 4,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': None,
#   'updated': '2022-02-08T03:45:03.580Z'},
#  {'corpusid': 208416034,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2981797085',
#    'CorpusId': '208416034',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/cfd97c7bd2d3fd303a933d1b8aa0ecdccf1a078d',
#   'title': 'Lice Infestation and Shortness of Breath in the ED',
#   'authors': [{'authorId': '78366217', 'name': 'B. Pregerson'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2019,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': [{'category': 'Medicine', 'source': 's2-fos-model'},
#    {'category': 'Medicine', 'source': 'external'}],
#   'publicationtypes': None,
#   'publicationdate': '2019-10-22',
#   'journal': {'name': '', 'pages': None, 'volume': ''},
#   'updated': '2022-02-08T03:54:52.651Z'},
#  {'corpusid': 201898382,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2892997179',
#    'CorpusId': '201898382',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/66428cc7fd761319c9c3ac2b0be54dd8032aa3c1',
#   'title': 'Wowen safety belt for vehicle occupant restraint system',
#   'authors': [{'authorId': '1414082758', 'name': '安德列亚斯·科尔布'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 1996,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': [{'category': 'Engineering', 'source': 's2-fos-model'},
#    {'category': 'Computer Science', 'source': 'external'}],
#   'publicationtypes': None,
#   'publicationdate': '1996-03-28',
#   'journal': {'name': '', 'pages': None, 'volume': ''},
#   'updated': '2022-02-08T05:01:48.981Z'},
#  {'corpusid': 199274039,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2787976701',
#    'CorpusId': '199274039',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/0bbb95c542e79398f58706bbfeb8813e05cded71',
#   'title': 'CHAMP MAGNÉTIQUE ROTATIF POUR AMÉLIORER LA DÉTECTION DANS DES ESSAIS SUR AGRÉGAT',
#   'authors': [{'authorId': '2079379071', 'name': 'Andrea Ranzoni'},
#    {'authorId': '151390832', 'name': 'J. PrinsMennoW'},
#    {'authorId': '151442400', 'name': 'M. OvsyankoMikhail'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2010,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': None,
#   'updated': '2022-02-08T05:47:22.869Z'},
#  {'corpusid': 198567339,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2955572471',
#    'CorpusId': '198567339',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/1284fe3e89b31472888eec741d0f56e8f86512f5',
#   'title': "Sidi Aich, vers la recoquete d'une nouvelle centralité",
#   'authors': [{'authorId': '151090398', 'name': 'Louiza Hamour'},
#    {'authorId': '151070925', 'name': 'K. Boudjema'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2018,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': '2018-06-01',
#   'journal': {'name': '', 'pages': None, 'volume': ''},
#   'updated': '2022-02-08T06:07:23.759Z'},
#  {'corpusid': 156378424,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2368733692',
#    'CorpusId': '156378424',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/71ae79c237ee7fba604116a1768ddc12c9c2af79',
#   'title': 'The Features and References of Teachers Training in German Vocational Colleges——Research Report on Studying and Training in Germany',
#   'authors': [{'authorId': '2072957585', 'name': 'Wang Jia'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2010,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': [{'category': 'Education', 'source': 's2-fos-model'},
#    {'category': 'Sociology', 'source': 'external'}],
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': None,
#   'updated': '2022-02-09T00:50:50.012Z'},
#  {'corpusid': 156397448,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2371104586',
#    'CorpusId': '156397448',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/ff3c133fdbdf2e9e14397b53dd5a018e5fa2cd78',
#   'title': 'On Building Modern State-owned Enterprise System with Chinese Characteristics and Tibetan Features',
#   'authors': [{'authorId': '2003358755', 'name': 'Mei Zhen'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2011,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': [{'category': 'Economics', 'source': 's2-fos-model'},
#    {'category': 'Business', 'source': 'external'}],
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': 'Tibetan Studies', 'pages': None, 'volume': ''},
#   'updated': '2022-02-09T00:48:33.298Z'},
#  {'corpusid': 152557616,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '1156468858',
#    'CorpusId': '152557616',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/32ebfb0d34258fd377e97cc6d1c934f650f844a4',
#   'title': 'Federalism and tax decentralization in Mexico',
#   'authors': [{'authorId': '1738453293', 'name': 'Nico Ramos'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2011,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': [{'category': 'Political Science',
#     'source': 's2-fos-model'},
#    {'category': 'Political Science', 'source': 'external'}],
#   'publicationtypes': None,
#   'publicationdate': '2011-09-12',
#   'journal': None,
#   'updated': '2022-02-09T02:48:11.449Z'},
#  {'corpusid': 149887672,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2810175962',
#    'CorpusId': '149887672',
#    'PubMed': None,
#    'DOI': '10.17107/KH.2018.16.248-255',
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/2f6e35f92a14e5838e85511281fc18c1b1b527c1',
#   'title': "Interesting Facts from the History of Hungarian Women's Competition Rowing. The Hungarian Rowing Association is 125 Years Old",
#   'authors': [{'authorId': '16210351', 'name': 'Anna Alliquander'},
#    {'authorId': '118299194', 'name': 'T. Tibori'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2018,
#   'referencecount': 8,
#   'citationcount': 1,
#   'influentialcitationcount': 0,
#   'isopenaccess': True,
#   's2fieldsofstudy': [{'category': 'Education', 'source': 's2-fos-model'},
#    {'category': 'History', 'source': 'external'}],
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': 'Kaleidoscope History',
#    'pages': '248-255',
#    'volume': '9'},
#   'updated': '2022-02-09T04:10:33.039Z'},
#  {'corpusid': 148291376,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2346478979',
#    'CorpusId': '148291376',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/8f61c889d6fb356a76ab64e41d95cd08f7af4fda',
#   'title': 'La gestion potentiel humaine dans la conduite du changement : vers une organisation favorisant un GRH moderne et dynamique.',
#   'authors': [{'authorId': '113921898', 'name': 'Rahmani Ahmed'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2006,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': '2006-03-21',
#   'journal': {'name': '', 'pages': None, 'volume': ''},
#   'updated': '2022-02-09T04:58:21.492Z'},
#  {'corpusid': 148580904,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2612942796',
#    'CorpusId': '148580904',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/7491de3ff845db051bd809dd5703cbc7d617cb2b',
#   'title': 'Penerapan Strategi Pembelajaran Index Card Matc (Mencari Pasangan) Untuk Meningkatkan Hasil Belajar Ipa Pokok Bahasan Tulang Siswa Kelas 4 SD Negeri Ketitangwetan 02 Semester I Tahun Ajaran 2012/2013',
#   'authors': [{'authorId': '2081595890', 'name': 'Darlan'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2013,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': '', 'pages': None, 'volume': ''},
#   'updated': '2022-02-09T04:49:04.002Z'},
#  {'corpusid': 148159215,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2491238321',
#    'CorpusId': '148159215',
#    'PubMed': None,
#    'DOI': '10.1075/ivitra.7.07bas',
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/e0ca7420f839ca5a2eaf07e23389ab5447b91143',
#   'title': 'Manlleus del castellà / Spanish loanword',
#   'authors': [{'authorId': '115136301', 'name': 'C. Bastida'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2014,
#   'referencecount': 2,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': [{'category': 'Linguistics', 'source': 's2-fos-model'},
#    {'category': 'Psychology', 'source': 'external'}],
#   'publicationtypes': None,
#   'publicationdate': '2014-10-15',
#   'journal': {'name': '', 'pages': '115-131', 'volume': ''},
#   'updated': '2022-02-09T05:02:37.558Z'},
#  {'corpusid': 148389518,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2472116662',
#    'CorpusId': '148389518',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/1193f91a116a4fa1e202fde07d30b0b7265f17bd',
#   'title': "S'endormir en séance : L'Analyste en séance",
#   'authors': [{'authorId': '7738633', 'name': 'O. Kerneis'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 1996,
#   'referencecount': 0,
#   'citationcount': 1,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': 'Topique', 'pages': '303-318', 'volume': '60'},
#   'updated': '2022-02-09T04:54:40.585Z'},
#  {'corpusid': 148201753,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2368655786',
#    'CorpusId': '148201753',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/4e2aed8e327cec34cbda25a3c4f5e1293d7b8e81',
#   'title': 'On the Corroboration of Confessions',
#   'authors': [{'authorId': '52402374', 'name': 'Zhang Ji-xi'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2007,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': [{'category': 'Psychology', 'source': 's2-fos-model'},
#    {'category': 'Psychology', 'source': 'external'}],
#   'publicationtypes': None,
#   'publicationdate': None,
#   'journal': {'name': 'Journal of Swupl', 'pages': None, 'volume': ''},
#   'updated': '2022-02-09T04:59:37.244Z'},
#  {'corpusid': 147622908,
#   'externalids': {'ACL': None,
#    'DBLP': None,
#    'ArXiv': None,
#    'MAG': '2262801688',
#    'CorpusId': '147622908',
#    'PubMed': None,
#    'DOI': None,
#    'PubMedCentral': None},
#   'url': 'https://www.semanticscholar.org/paper/66e8ebec9414b117251d955bd86ec87cf7b5f024',
#   'title': 'Pengaruh Penugasan Menyimak Individual pada Kemampuan Menyimak Wacana Bahasa Inggris',
#   'authors': [{'authorId': '2079943332', 'name': 'B. Cahyono'},
#    {'authorId': '114763336', 'name': 'Maryusman Maryusman'},
#    {'authorId': '120024990', 'name': 'Emalia Iragiliati'},
#    {'authorId': '2076683165', 'name': 'Utari Praba Astuti'}],
#   'venue': '',
#   'publicationvenueid': None,
#   'year': 2009,
#   'referencecount': 0,
#   'citationcount': 0,
#   'influentialcitationcount': 0,
#   'isopenaccess': False,
#   's2fieldsofstudy': None,
#   'publicationtypes': None,
#   'publicationdate': '2009-02-16',
#   'journal': {'name': '', 'pages': None, 'volume': '4'},
#   'updated': '2022-02-09T05:21:25.246Z'}]

# %%
all_embeddings = embed(papers)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 all_embeddings = embed(papers)
#
# Cell In[48], line 38, in embed(papers)
#      35 response = requests.post(URL, json=chunk)
#      37 if response.status_code != 200:
# ---> 38     raise RuntimeError("Sorry, something went wrong, please try later!")
#      40 for paper in response.json()["preds"]:
#      41     embeddings_by_paper_id[paper["paper_id"]] = paper["embedding"]
#
# RuntimeError: Sorry, something went wrong, please try later!

# %%
all_embeddings
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 all_embeddings
#
# NameError: name 'all_embeddings' is not defined

# %% [markdown]
# # Upload Text

# %% [markdown]
# Create connection and add "pool" object to environment. Used for connecting to DB

# %%
# 
exec(open(os.path.join(working_path, 'sql_db_connection.py')).read())
pool

# %% [markdown]
# ## Create Table

# %%
meta = MetaData()

articles = Table(
    'article_text', meta,
    Column('corpusid', Integer, primary_key = True),
    Column('externalids', String),
    Column('url', String),
    Column('title', Integer),
    Column('authors', ARRAY(JSONB)),
    Column('venue', String),
    Column('publicationvenueid', Integer),
    Column('year', String),
    Column('referencecount', Integer),
    Column('citationcount', Integer),
    Column('influentialcitationcount', Integer),
    Column('isopenaccess', Boolean),
    Column('s2fieldsofstudy', ARRAY(JSONB)),
    Column('publicationtypes', Integer),
    Column('publicationdate', Integer),
    Column('journal', JSONB),
    Column('updated', String)    
)

# create table in database
meta.create_all(pool)

# %% [markdown]
# ## Start Upload
