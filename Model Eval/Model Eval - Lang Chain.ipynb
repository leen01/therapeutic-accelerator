# %%
import pandas as _hex_pandas
import datetime as _hex_datetime
import json as _hex_json

# %%
hex_scheduled = _hex_json.loads("false")

# %%
hex_user_email = _hex_json.loads("\"example-user@example.com\"")

# %%
hex_run_context = _hex_json.loads("\"logic\"")

# %%
hex_timezone = _hex_json.loads("\"UTC\"")

# %%
hex_project_id = _hex_json.loads("\"b8620bad-42b0-49f3-86ee-5b1177273026\"")

# %%
hex_color_palette = _hex_json.loads("[\"#4C78A8\",\"#F58518\",\"#E45756\",\"#72B7B2\",\"#54A24B\",\"#EECA3B\",\"#B279A2\",\"#FF9DA6\",\"#9D755D\",\"#BAB0AC\"]")

# %%
# import jinja2
# raw_query = """
#     select fulltext.corpusid, abstract, fulltext.text
#     from abstract_encodings_test4
#     JOIN fulltext on fulltext.corpusid_int = abstract_encodings_test4.corpusid
#     order by random()
#     limit 1000
#     
#     
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
# %pip install langchain==0.0.237
# %pip install rouge_score


from langchain.chains.question_answering import load_qa_chain
from langchain.chains.summarize import load_summarize_chain
from langchain.docstore.document import Document
from langchain.text_splitter import CharacterTextSplitter
from langchain import OpenAI 
from rouge_score import rouge_scorer
import pandas as pd

openai_api_key = "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"

llm = OpenAI(temperature=0.5, openai_api_key = openai_api_key)

text_splitter = CharacterTextSplitter(chunk_size=7000, chunk_overlap=0)

chain = load_summarize_chain(llm, chain_type="map_reduce")
# Out:
# ...
#   Obtaining dependency information for langchain==0.0.237 from https://files.pythonhosted.org/packages/89/b1/73ba21a11f8ddba3d0f867f02412ee97e598fac29365a60a3a46556ac2a0/langchain-0.0.237-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for aiohttp<4.0.0,>=3.8.3 from https://files.pythonhosted.org/packages/3e/f6/fcda07dd1e72260989f0b22dde999ecfe80daa744f23ca167083683399bc/aiohttp-3.8.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...
#   Obtaining dependency information for dataclasses-json<0.6.0,>=0.5.7 from https://files.pythonhosted.org/packages/97/5f/e7cc90f36152810cab08b6c9c1125e8bcb9d76f8b3018d101b5f877b386c/dataclasses_json-0.5.14-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for langsmith<0.0.11,>=0.0.10 from https://files.pythonhosted.org/packages/a9/ed/9813d7c199e705865902fdc1e2076b588d6f93ffac93d37f4b50a5205a1b/langsmith-0.0.10-py3-none-any.whl.metadata
# ...

# %%
df_scores = pd.DataFrame(columns = ["CorpusID", "Summary", "Abstract","ROUGE Percision", "ROUGE Recal", "ROUGE F1"])

for i in range(0,1000):

    corp_id = vector_similarity.loc[i]['corpusid']
    reference = vector_similarity.loc[i]['abstract']
    text = text_splitter.split_text(reference)
    docs = [Document(page_content=t) for t in text[:3]]
    candidate = chain.run(docs)

    scorer = rouge_scorer.RougeScorer(["rouge1", "rouge2"],  use_stemmer=True )
    rouge_scorer_obj =(scorer.score(reference, candidate))

    r_percision = rouge_scorer_obj['rouge2'][0]
    r_recall = rouge_scorer_obj['rouge2'][1]
    r_f1 = rouge_scorer_obj['rouge2'][2]

    row = [corp_id, candidate, reference, r_percision, r_recall, r_f1]
    df_scores.loc[len(df_scores)] = row

# %%
print (df_scores['ROUGE F1'].mean())
print (df_scores['ROUGE Recal'].mean())
print (df_scores['ROUGE Percision'].mean())
# Out:
# 0.2418106575956452
# 0.16662269972497334
# 0.5164558909796024

# %%
df_scores_1 = pd.DataFrame(columns = ["CorpusID", "Summary", "Text","ROUGE Percision", "ROUGE Recal", "ROUGE F1"])

for i in range(0,1000):

    try: 
            
        corp_id = vector_similarity.loc[i]['corpusid']
        reference = vector_similarity.loc[i]['abstract']
        full_text = vector_similarity.loc[i]['text']

        text = text_splitter.split_text(full_text)
        docs = [Document(page_content=t) for t in text[:3]]
        candidate = chain.run(docs)

        scorer = rouge_scorer.RougeScorer(["rouge1", "rouge2"],  use_stemmer=True )
        rouge_scorer_obj =(scorer.score(reference, candidate))

        r_percision = rouge_scorer_obj['rouge2'][0]
        r_recall = rouge_scorer_obj['rouge2'][1]
        r_f1 = rouge_scorer_obj['rouge2'][2]

        row = [corp_id, candidate, reference, r_percision, r_recall, r_f1]
        df_scores_1.loc[len(df_scores_1)] = row
    except: 
        print ("error: ", i)
# Out:
# WARNING:langchain.llms.base:Retrying langchain.llms.openai.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised APIConnectionError: Error communicating with OpenAI: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')).
# error:  35
# WARNING:langchain.text_splitter:Created a chunk of size 9181, which is longer than the specified 7000

# %%
print (df_scores_1['ROUGE F1'].mean())
print (df_scores_1['ROUGE Recal'].mean())
print (df_scores_1['ROUGE Percision'].mean())
# Out:
# 0.17807357477501162
# 0.12915691702912507
# 0.327621322002175
