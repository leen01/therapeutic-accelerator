# %% [markdown]
# # Imports

# %%
from langchain.llms import OpenAI
from langchain import PromptTemplate, SagemakerEndpoint
from langchain.llms.sagemaker_endpoint import LLMContentHandler
from langchain.chains.question_answering import load_qa_chain
from langchain.chains.summarize import load_summarize_chain
import json
from langchain.document_loaders import TextLoader
from langchain.document_loaders.csv_loader import CSVLoader
from langchain.document_loaders import JSONLoader
from langchain.document_loaders import PyPDFLoader
from langchain.docstore.document import Document
from langchain.text_splitter import CharacterTextSplitter
from pathlib import Path
from pprint import pprint
from langchain import OpenAI, PromptTemplate, LLMChain
from langchain.chains.mapreduce import MapReduceChain
from langchain.prompts import PromptTemplate

import os
from glob import glob
import requests
import urllib
from sqlalchemy import text
from langchain.chains import RetrievalQA
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma

import pandas as pd
import numpy as np
import csv
from metapub import PubMedFetcher

import yaml
from sqlalchemy import create_engine

# %%
# import functions from a file stored in a different directory
import sys
sys.path.append('/home/ubuntu/work/therapeutic_accelerator/scripts/utils')
sys.path.append('/home/ubuntu/work/therapeutic_accelerator/scripts/database')

from db_tools import db_connection
from utils import import_config

config, keys = import_config()

engine = db_connection(
    password=keys["postgres"], host=config["database"]["host"])

# %% [markdown]
# # Load Data

# %%
# Retreive Full Text from Table
table_name = "fulltext"

sql = text(
    f""" 
    SELECT * FROM {table_name} LIMIT 10;
"""
)

with engine.connect() as conn:
    query = conn.execute(sql)

full_text = pd.DataFrame(query.fetchall())
full_text.head()
# Out:
#   empty Unnamed: 0   corpusid  \
# 0  1410       1410  250929149
# 1  1411       1411  215793097
# 2  1412       1412  246020601
# 3  1413       1413   18163935
# 4  1414       1414  237935836
#
#                                                 text source.pdfurls  \
# 0  \nOPEN ACCESS EDITED BY\n\n\nAlexander Nikolae...           None
# 1  \n\n\n\nCi Song \nState Key Laboratory of Repr...           None
# 2  \nCOVID-19 and the Otolaryngology Residency Ma...           None
# 3  \nAnalysis of biophysical and functional conse...           None
# 4  \nImpact of Plant-Based Meat Alternatives on t...           None
#
#                               source.pdfsha source.oainfo  \
# 0  57f2173016853ed6f6406a962adb11da43917165          None
# 1  be45f9e9d6d1f4f713546b943cb2ff455989adc2          None
# 2  b7decbb79e55bb3c9b5430bef4323775813c39e0          None
# 3  895fdf69460791863817c037332c0403c3e917b1          None
# 4  acf534c72039d2b2c10544b12f7cc872c2ba1b2a          None
#
#          annotations.abstract  \
# 0                        None
# 1                        None
# 2  [{"end":2210,"start":391}]
# 3  [{"end":1608,"start":861}]
# 4                        None
#
#                                   annotations.author  \
# 0  [{"end":55,"start":25},{"end":69,"start":56},{...
# 1  [{"end":228,"start":4},{"end":380,"start":229}...
# 2  [{"end":109,"start":85},{"end":127,"start":110...
# 3  [{"end":217,"start":201},{"end":235,"start":21...
# 4  [{"end":289,"start":123},{"end":375,"start":29...
#
#                        annotations.authoraffiliation  ...  \
# 0  [{"end":455,"start":306},{"end":1102,"start":4...  ...
# 1  [{"end":104,"start":13},{"end":227,"start":106...  ...
# 2                                               None  ...
# 3  [{"end":363,"start":257},{"end":410,"start":366}]  ...
# 4  [{"end":219,"start":148},{"end":288,"start":22...  ...
#
#   annotations.publisher                          annotations.sectionheader  \
# 0                  None  [{"end":3001,"start":2989},{"end":6895,"start"...
# 1                  None                        [{"end":8781,"start":8771}]
# 2                  None  [{"end":2224,"start":2212},{"end":4135,"start"...
# 3                  None  [{"end":7790,"start":7769},{"end":7810,"start"...
# 4                  None  [{"attributes":{"n":"1."},"end":1115,"start":1...
#
#                                    annotations.table  \
# 0  [{"end":35560,"start":34552},{"end":38099,"sta...
# 1                                               None
# 2  [{"end":16114,"start":15573},{"end":16650,"sta...
# 3                      [{"end":32871,"start":32129}]
# 4  [{"end":60480,"start":59841},{"end":61332,"sta...
#
#                                 annotations.tableref  \
# 0  [{"end":18195,"start":18188},{"end":18790,"sta...
# 1                        [{"end":4906,"start":4898}]
# 2  [{"attributes":{"ref_id":"tab_0"},"end":7027,"...
# 3  [{"attributes":{"ref_id":"tab_0"},"end":12397,...
# 4  [{"attributes":{"ref_id":"tab_1"},"end":8301,"...
#
#                                   annotations.title annotations.venue  \
# 0  [{"end":22,"start":1},{"end":1721,"start":1700}]              None
# 1                                              None              None
# 2    [{"end":82,"start":1},{"end":227,"start":146}]              None
# 3    [{"end":95,"start":1},{"end":506,"start":412}]              None
# 4    [{"end":95,"start":1},{"end":755,"start":661}]              None
#
#   source.oainfo.license                        source.oainfo.openaccessurl  \
# 0                  None                                               None
# 1                  None  https://academic.oup.com/biolreprod/article-pd...
# 2                  None  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9...
# 3                  CCBY            https://doi.org/10.1002/1873-3468.12346
# 4                  CCBY       https://www.mdpi.com/2304-8158/10/9/2040/pdf
#
#   source.oainfo.status id
# 0                 None  1
# 1               BRONZE  2
# 2                GREEN  3
# 3               HYBRID  4
# 4                 GOLD  5
#
# [5 rows x 34 columns]

# %%
# Mount google drive
# drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Paths
# main_path = "/content/drive/MyDrive/"
# capstone_directory = main_path + "w210_Capstone_Therapeutic_Accelerator/"
# starter_data = capstone_directory + "data"

# %%
starter_data
# Out:
# '/content/drive/MyDrive/w210_Capstone_Therapeutic_Accelerator/data'

# %%
# attributes_csv = starter_data + "/final.csv"
# attributes_df = pd.read_csv(attributes_csv)
# attributes_df.head(10)
# Out:
#    Unnamed: 0   corpusid                                        externalids  \
# 0           0   52273203  {"ACL": null, "DBLP": null, "ArXiv": null, "MA...
# 1           1   23708908  {"ACL": null, "DBLP": null, "ArXiv": null, "MA...
# 2           2   13232625  {"ACL": null, "DBLP": null, "ArXiv": null, "MA...
# 3           3   73484844  {"ACL": null, "DBLP": null, "ArXiv": null, "MA...
# 4           4  229159752  {"ACL": null, "DBLP": null, "ArXiv": null, "MA...
# 5           5   10041098  {"ACL": null, "DBLP": null, "ArXiv": null, "MA...
# 6           6   19472375  {"ACL": null, "DBLP": null, "ArXiv": null, "MA...
# 7           7  219603447  {"ACL": null, "DBLP": null, "ArXiv": null, "MA...
# 8           8   15826244  {"ACL": null, "DBLP": null, "ArXiv": null, "MA...
# 9           9    2311509  {"ACL": null, "DBLP": null, "ArXiv": null, "MA...
#
#                                                  url  \
# 0  https://www.semanticscholar.org/paper/39063bcd...
# 1  https://www.semanticscholar.org/paper/6ec7c156...
# 2  https://www.semanticscholar.org/paper/c8566272...
# 3  https://www.semanticscholar.org/paper/d4c9b2fa...
# 4  https://www.semanticscholar.org/paper/7f13abe2...
# 5  https://www.semanticscholar.org/paper/92b26dee...
# 6  https://www.semanticscholar.org/paper/2c682757...
# 7  https://www.semanticscholar.org/paper/9b9659a4...
# 8  https://www.semanticscholar.org/paper/314f8d8a...
# 9  https://www.semanticscholar.org/paper/7a0b4601...
#
#                                                title  \
# 0  Large conformational changes of a highly dynam...
# 1  Drug sensitivity profiling identifies potentia...
# 2  Men's memory for women's sexual-interest and r...
# 3  The Reactive Plasticity of Hippocampal Ionotro...
# 4  High Mortality Rate in Adult COVID-19 Inpatien...
# 5  NADH-dependent metabolism of nitric oxide in a...
# 6  Aspects of posttraumatic stress disorder in lo...
# 7  Multicenter assessment of the Brain Injury Gui...
# 8  Mycobacterium haemophilum as the Initial Prese...
# 9  Up-regulation and subcellular localization of ...
#
#                                              authors  \
# 0  {"{\"authorId\": \"51285510\", \"name\": \"Isa...
# 1  {"{\"authorId\": \"5699001\", \"name\": \"H. K...
# 2  {"{\"authorId\": \"4425040\", \"name\": \"T. T...
# 3  {"{\"authorId\": \"2225106\", \"name\": \"A. M...
# 4  {"{\"authorId\": \"7685173\", \"name\": \"Saee...
# 5  {"{\"authorId\": \"1792255\", \"name\": \"A. I...
# 6  {"{\"authorId\": \"2000616\", \"name\": \"A. D...
# 7  {"{\"authorId\": \"145776250\", \"name\": \"Ab...
# 8  {"{\"authorId\": \"2060804071\", \"name\": \"T...
# 9  {"{\"authorId\": \"14726800\", \"name\": \"Hua...
#
#                                          venue  \
# 0                       Communications Biology
# 1                                   OncoTarget
# 2                                          NaN
# 3  International Journal of Molecular Sciences
# 4      Journal of Multidisciplinary Healthcare
# 5                                       Planta
# 6               Journal of cancer survivorship
# 7             Trauma Surgery & Acute Care Open
# 8                 Case Reports in Rheumatology
# 9                                   BMC Cancer
#
#                      publicationvenueid    year  referencecount  \
# 0  069e05e7-ca35-41d0-a8c7-bdc9ec6a82af  2018.0              28
# 1  106ecc86-1801-4b36-a05c-d36db69a968c  2017.0              46
# 2                                   NaN  2011.0              36
# 3  8506a01a-40b8-4e6f-bbb8-ce2492139c15  2019.0              97
# 4  12e5e550-28bd-401c-a348-f347956deec4  2020.0              37
# 5  66507f0b-12a1-4058-a35c-73029853d5b9  2004.0              30
# 6  649b7693-cb10-4892-b8a2-65b9b51fcd50  2016.0              33
# 7  d40f33e8-6f79-4e91-a62e-acf29f9a3e2f  2020.0              35
# 8  884ab217-3965-4a74-90d1-003d0b378d6d  2014.0              24
# 9  b482a99f-ef53-4694-aec6-32ad78e0d716  2010.0              58
#
#    citationcount  influentialcitationcount  isopenaccess  \
# 0             13                         0          True
# 1             24                         0          True
# 2             13                         0          True
# 3             15                         1          True
# 4             17                         1          True
# 5            145                         3         False
# 6             18                         0         False
# 7             11                         0          True
# 8              8                         0          True
# 9             44                         0          True
#
#                                      s2fieldsofstudy         publicationtypes  \
# 0  {"{\"category\": \"Biology\", \"source\": \"s2...         {JournalArticle}
# 1  {"{\"category\": \"Biology\", \"source\": \"s2...         {JournalArticle}
# 2  {"{\"category\": \"Psychology\", \"source\": \...                 {Review}
# 3  {"{\"category\": \"Biology\", \"source\": \"s2...  {Review,JournalArticle}
# 4  {"{\"category\": \"Medicine\", \"source\": \"s...  {JournalArticle,Review}
# 5  {"{\"category\": \"Biology\", \"source\": \"s2...         {JournalArticle}
# 6  {"{\"category\": \"Psychology\", \"source\": \...         {JournalArticle}
# 7  {"{\"category\": \"Medicine\", \"source\": \"s...  {JournalArticle,Review}
# 8  {"{\"category\": \"Medicine\", \"source\": \"s...         {JournalArticle}
# 9  {"{\"category\": \"Biology\", \"source\": \"s2...         {JournalArticle}
#
#   publicationdate                                            journal  \
# 0      2018-09-03  {"name": "Communications Biology", "pages": nu...
# 1      2017-10-31  {"name": "Oncotarget", "pages": "97516 - 97527...
# 2      2011-09-01  {"name": "Applied Cognitive Psychology", "page...
# 3      2019-02-27  {"name": "International Journal of Molecular S...
# 4      2020-12-01  {"name": "Journal of Multidisciplinary Healthc...
# 5      2004-01-22  {"name": "Planta", "pages": "95-102", "volume"...
# 6      2016-02-26  {"name": "Journal of Cancer Survivorship", "pa...
# 7      2020-05-01  {"name": "Trauma Surgery & Acute Care Open", "...
# 8      2014-01-12  {"name": "Case Reports in Rheumatology", "page...
# 9      2010-07-06  {"name": "BMC Cancer", "pages": "356 - 356", "...
#
#                     updated       id
# 0  2023-03-31T01:28:37.897Z  5692596
# 1  2023-04-05T06:18:15.837Z  5692609
# 2  2023-04-05T08:18:02.240Z  5692611
# 3  2023-05-20T17:20:54.230Z  5692615
# 4  2023-05-23T13:34:07.581Z  5692620
# 5  2023-04-05T15:01:41.273Z  5692625
# 6  2023-04-05T19:07:12.948Z  5692626
# 7  2023-04-07T01:56:26.282Z  5692637
# 8  2023-04-07T01:15:17.667Z  5692638
# 9  2023-04-07T01:28:15.493Z  5692639

# %%
full_doc_example = full_text["text"][8]
full_doc_example
# Out:
# '\nRelation between quantity and quality of peri-coronary epicardial adipose tissue and its underlying hemodynamically significant coronary stenosis\n\n\nYu Du \n† \nLin Yang \nYan Liu \nBangguo Yang \nSai Lv \nChenping Hu \nYong Zhu \nHongkai Zhang \nQian Ma \nZhijian Wang \nYuyang Liu \nDongmei Shi \nYingxin Zhao \nLei Xu \nYujie Zhou \nRelation between quantity and quality of peri-coronary epicardial adipose tissue and its underlying hemodynamically significant coronary stenosis\n10.1186/s12872-020-01499-wR E S E A R C H A R T I C L E Open Access\nBackground: We aimed to investigate the association of lesion-specific epicardial adipose tissue (EAT) volume and density with the presence of myocardial ischemia.Methods:We enrolled 45 patients (55 lesions) with known or suspected coronary artery disease who underwent coronary computed tomography angiography (CTA) followed by invasive fractional flow reserve (FFR) assessment within 30 days. EAT volume (index) and density in patient-, vessel-and lesion-level were measured on CTA images. Lesion-specific ischemia was defined as a lesion with stenosis diameter > 90% or FFR ≤0.80. Multivariate analysis determined the independent association of EAT parameters with lesion-specific ischemia. Results: Mean age of the patients was 60 years, and 75% were male. Overall, 55.6% of patients had ischemic lesions and a mean FFR baseline value of 0.82 ± 0.10. Total EAT volume index was significantly higher in patients with functionally or anatomically significant stenosis. Specifically, peri-lesion EAT volume index, not the density, was positively correlated with lesion-specific ischemia independent of luminal stenosis and plaque characteristics (hazard ratio 1.56, 95% confidence interval 1.04-2.33, P = 0.032; per 0.1 ml/m 2 increase). Moreover, peri-lesion EAT volume was negatively correlated with lesion FFR values, whereas total EAT volume was positively correlated with fat accumulation and glucose metabolism. In addition, there was no association of EAT volume or density with myocardial ischemia in vessel-level analysis.Conclusions: Lesion-specific EAT volume index, but not density, seems positively and independently associated with myocardial ischemia, while its incremental diagnostic value of lesion-specific ischemia should be further investigated.\n\nBackground\n\nEpicardial adipose tissue (EAT) is a specific fat depot between the myocardium and the visceral pericardium, mainly surrounding major epicardial coronary arteries or within the myocardium [1]. Numerous studies showed that the accumulation of EAT is closely associated with the presence and severity of coronary artery disease (CAD), myocardial ischemia, plaque vulnerability, and major adverse cardiovascular events (MACE) [2][3][4][5]. However, not all patients with increased EAT volume develop CAD and vice versa.\n\nTo further explain the relation between EAT and CAD, the following two factors are attracting much attention. The first one is peri-coronary EAT, because there is close cross-talk between this focal metaboloactive EAT and its underlying coronary wall via a paracrine pathway [6]. External administration of interleukin 1β or monocyte chemotactic protein 1 to porcine coronary arteries led to coronary wall inflammation and atherosclerosis formation [7,8], while surgical removal of peri-coronary EAT ameliorated the progression of coronary atherosclerosis in the pigs [9]. The second important factor is EAT quality, shown as fat attenuation on computed tomography (CT), which reveals adipocyte lipid content and size, reflecting a metabolic response to cardiovascular risk factors [10]. Antonopoulos et al. found that the peri-coronary EAT attenuation index can expose vascular inflammation, subclinical coronary atherosclerosis, and vulnerable plaque [11] and even independently predict cardiac mortality [12].\n\nAccordingly, it is theoretically feasible to determine the hemodynamic significance and vulnerability of coronary stenosis  ...

# %%
openai_api_key = "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"

llm = OpenAI(temperature=0.5, openai_api_key=openai_api_key)

text_splitter = CharacterTextSplitter()

# %%
# Use text_splitter to split documents
# Use Documents package to format text
text = text_splitter.split_text(full_doc_example)
docs = [Document(page_content=t) for t in text[:3]]

chain = load_summarize_chain(llm, chain_type="map_reduce")
chain.run(docs)
# Out:
# ' This study investigated the association between lesion-specific epicardial adipose tissue (EAT) volume and density with the presence of myocardial ischemia in a hospital-based Chinese population. Results showed that peri-lesion EAT volume index was positively correlated with lesion-specific ischemia, negatively correlated with lesion FFR values, and positively correlated with fat accumulation and glucose metabolism. These results suggest that lesion-specific EAT volume index may be independently associated with myocardial ischemia.'
